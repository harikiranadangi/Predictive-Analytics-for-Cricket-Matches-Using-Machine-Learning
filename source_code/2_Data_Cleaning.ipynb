# %%
import pandas as  pd
df = pd.read_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\match_summary.csv", low_memory=False)
#df.drop(columns="Unnamed: 0", inplace=True)
print("Length of Data Frame:", len(df))
df.head(1)
# Out:
# Length of Data Frame: 18908
#    balls_per_over   city                                              dates  \
# 0               6  Perth  ['2016-11-03', '2016-11-04', '2016-11-05', '20...
#
#    event.match_number                             event.name gender  \
# 0                 1.0  South Africa in Australia Test Series   male
#
#   match_type  match_type_number officials.match_referees  \
# 0       Test             2230.0           ['AJ Pycroft']
#
#   officials.reserve_umpires  ... event.sub_name outcome.result  \
# 0           ['SJ Nogajski']  ...            NaN            NaN
#
#    outcome.method missing event.stage event.group outcome.eliminator  \
# 0             NaN     NaN         NaN         NaN                NaN
#
#   toss.uncontested bowl_out outcome.bowl_out
# 0              NaN      NaN              NaN
#
# [1 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['balls_per_over', 'city', 'dates', 'event.match_number', 'event.name',
#        'gender', 'match_type', 'match_type_number', 'officials.match_referees',
#        'officials.reserve_umpires', 'officials.tv_umpires',
#        'officials.umpires', 'outcome.by.runs', 'outcome.winner',
#        'player_of_match', 'season', 'team_type', 'teams', 'toss.decision',
#        'toss.winner', 'venue', 'match_id', 'outcome.by.innings',
#        'outcome.by.wickets', 'overs', 'event.sub_name', 'outcome.result',
#        'outcome.method', 'missing', 'event.stage', 'event.group',
#        'outcome.eliminator', 'toss.uncontested', 'bowl_out',
#        'outcome.bowl_out'],
#       dtype='object')

# %%
df.drop(columns=['balls_per_over','outcome.by.runs',"match_type_number", 'overs','outcome.by.innings','event.match_number','outcome.by.wickets', 'officials.umpires','outcome.method',  'missing',  
                 'officials.reserve_umpires', 'officials.match_referees',"team_type", 'bowl_out',"officials.tv_umpires","event.stage",'event.sub_name', "player_of_match",'event.stage', 'event.group','toss.uncontested',
                 'outcome.bowl_out'], inplace=True)

# %%
df.head()
# Out:
#        city                                              dates  \
# 0     Perth  ['2016-11-03', '2016-11-04', '2016-11-05', '20...
# 1    Hobart  ['2016-11-12', '2016-11-13', '2016-11-14', '20...
# 2       NaN  ['2016-11-24', '2016-11-25', '2016-11-26', '20...
# 3  Brisbane  ['2016-12-15', '2016-12-16', '2016-12-17', '20...
# 4       NaN  ['2016-12-26', '2016-12-27', '2016-12-28', '20...
#
#                               event.name gender match_type outcome.winner  \
# 0  South Africa in Australia Test Series   male       Test   South Africa
# 1  South Africa in Australia Test Series   male       Test   South Africa
# 2  South Africa in Australia Test Series   male       Test      Australia
# 3      Pakistan in Australia Test Series   male       Test      Australia
# 4      Pakistan in Australia Test Series   male       Test      Australia
#
#     season                          teams toss.decision   toss.winner  \
# 0  2016/17  ['Australia', 'South Africa']           bat  South Africa
# 1  2016/17  ['Australia', 'South Africa']         field  South Africa
# 2  2016/17  ['Australia', 'South Africa']           bat  South Africa
# 3  2016/17      ['Australia', 'Pakistan']           bat     Australia
# 4  2016/17      ['Australia', 'Pakistan']           bat      Pakistan
#
#                                           venue match_id outcome.result  \
# 0  Western Australia Cricket Association Ground  1000851            NaN
# 1                                Bellerive Oval  1000853            NaN
# 2                                 Adelaide Oval  1000855            NaN
# 3        Brisbane Cricket Ground, Woolloongabba  1000881            NaN
# 4                      Melbourne Cricket Ground  1000883            NaN
#
#   outcome.eliminator
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
df[df["dates"] == "['2020-10-03', '2020-10-04']"]
# Out:
#             city                         dates      event.name gender  \
# 4952  Birmingham  ['2020-10-03', '2020-10-04']  Vitality Blast   male
#
#      match_type outcome.winner season                          teams  \
# 4952        T20         Surrey   2020  ['Gloucestershire', 'Surrey']
#
#      toss.decision toss.winner      venue match_id outcome.result  \
# 4952         field      Surrey  Edgbaston  1229397            NaN
#
#      outcome.eliminator
# 4952                NaN

# %% [markdown]
# ### **Creating Date Column**

# %%
# Clean up the dates column
df['dates'] = df['dates'].str.strip("[]").str.replace("'", "").str.strip()

# Extract the latest date in cases where there are multiple dates
def extract_latest_date(date_str):
    dates = date_str.split(', ')
    if len(dates) > 1:
        return dates[-1]
    else:
        return dates[0]

df['dates'] = df['dates'].apply(extract_latest_date)

# Convert the dates to datetime format
df['dates'] = pd.to_datetime(df['dates'], errors='coerce')

# Sort DataFrame by dates
df = df.sort_values(by="dates", ascending=False)

df[:10]
# Out:
#              city      dates                            event.name  gender  \
# 13401     Lucknow 2025-05-23                 Indian Premier League    male
# 13459      Lahore 2025-05-23                 Pakistan Super League    male
# 13333      Dublin 2025-05-23           West Indies tour of Ireland    male
# 12557    Brighton 2025-05-23     West Indies Women tour of England  female
# 13400   Ahmedabad 2025-05-22                 Indian Premier League    male
# 13458      Lahore 2025-05-22                 Pakistan Super League    male
# 12556  Canterbury 2025-05-21     West Indies Women tour of England  female
# 13457      Lahore 2025-05-21                 Pakistan Super League    male
# 13599  Lauderhill 2025-05-21  ICC Men's Cricket World Cup League 2    male
# 13332      Dublin 2025-05-21           West Indies tour of Ireland    male
#
#       match_type        outcome.winner season  \
# 13401        T20   Sunrisers Hyderabad   2025
# 13459        T20      Lahore Qalandars   2025
# 13333        ODI                   NaN   2025
# 12557        T20               England   2025
# 13400        T20  Lucknow Super Giants   2025
# 13458        T20      Lahore Qalandars   2025
# 12556        T20               England   2025
# 13457        T20     Quetta Gladiators   2025
# 13599        ODI                   NaN   2025
# 13332        ODI               Ireland   2025
#
#                                                    teams toss.decision  \
# 13401  ['Sunrisers Hyderabad', 'Royal Challengers Ben...         field
# 13459           ['Lahore Qalandars', 'Islamabad United']           bat
# 13333                         ['West Indies', 'Ireland']         field
# 12557                         ['West Indies', 'England']         field
# 13400         ['Lucknow Super Giants', 'Gujarat Titans']         field
# 13458              ['Karachi Kings', 'Lahore Qalandars']           bat
# 12556                         ['West Indies', 'England']         field
# 13457          ['Quetta Gladiators', 'Islamabad United']           bat
# 13599               ['Oman', 'United States of America']         field
# 13332                         ['Ireland', 'West Indies']         field
#
#                        toss.winner  \
# 13401  Royal Challengers Bengaluru
# 13459             Lahore Qalandars
# 13333                      Ireland
# 12557                      England
# 13400               Gujarat Titans
# 13458                Karachi Kings
# 12556                      England
# 13457            Quetta Gladiators
# 13599     United States of America
# 13332                  West Indies
#
#                                                    venue match_id  \
# 13401  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  1473503
# 13459                            Gaddafi Stadium, Lahore  1475270
# 13333                              Castle Avenue, Dublin  1472512
# 12557                                County Ground, Hove  1448392
# 13400                   Narendra Modi Stadium, Ahmedabad  1473502
# 13458                            Gaddafi Stadium, Lahore  1475269
# 12556                     St Lawrence Ground, Canterbury  1448391
# 13457                            Gaddafi Stadium, Lahore  1475268
# 13599  Central Broward Regional Park Stadium Turf Gro...  1482566
# 13332                              Castle Avenue, Dublin  1472511
#
#       outcome.result outcome.eliminator
# 13401            NaN                NaN
# 13459            NaN                NaN
# 13333      no result                NaN
# 12557            NaN                NaN
# 13400            NaN                NaN
# 13458            NaN                NaN
# 12556            NaN                NaN
# 13457            NaN                NaN
# 13599            tie               Oman
# 13332            NaN                NaN

# %%
df[df["match_id"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [city, dates, event.name, gender, match_type, outcome.winner, season, teams, toss.decision, toss.winner, venue, match_id, outcome.result, outcome.eliminator]
# Index: []

# %%
# Drop duplicates based on 'match_id' and reset the index in the original DataFrame
df.drop_duplicates(subset="match_id", inplace=True)
df.reset_index(drop=True, inplace=True)

# Print the resulting DataFrame to verify
df[:10]
# Out:
#          city      dates                            event.name  gender  \
# 0     Lucknow 2025-05-23                 Indian Premier League    male
# 1      Lahore 2025-05-23                 Pakistan Super League    male
# 2      Dublin 2025-05-23           West Indies tour of Ireland    male
# 3    Brighton 2025-05-23     West Indies Women tour of England  female
# 4   Ahmedabad 2025-05-22                 Indian Premier League    male
# 5      Lahore 2025-05-22                 Pakistan Super League    male
# 6  Canterbury 2025-05-21     West Indies Women tour of England  female
# 7      Lahore 2025-05-21                 Pakistan Super League    male
# 8  Lauderhill 2025-05-21  ICC Men's Cricket World Cup League 2    male
# 9      Dublin 2025-05-21           West Indies tour of Ireland    male
#
#   match_type        outcome.winner season  \
# 0        T20   Sunrisers Hyderabad   2025
# 1        T20      Lahore Qalandars   2025
# 2        ODI                   NaN   2025
# 3        T20               England   2025
# 4        T20  Lucknow Super Giants   2025
# 5        T20      Lahore Qalandars   2025
# 6        T20               England   2025
# 7        T20     Quetta Gladiators   2025
# 8        ODI                   NaN   2025
# 9        ODI               Ireland   2025
#
#                                                teams toss.decision  \
# 0  ['Sunrisers Hyderabad', 'Royal Challengers Ben...         field
# 1           ['Lahore Qalandars', 'Islamabad United']           bat
# 2                         ['West Indies', 'Ireland']         field
# 3                         ['West Indies', 'England']         field
# 4         ['Lucknow Super Giants', 'Gujarat Titans']         field
# 5              ['Karachi Kings', 'Lahore Qalandars']           bat
# 6                         ['West Indies', 'England']         field
# 7          ['Quetta Gladiators', 'Islamabad United']           bat
# 8               ['Oman', 'United States of America']         field
# 9                         ['Ireland', 'West Indies']         field
#
#                    toss.winner  \
# 0  Royal Challengers Bengaluru
# 1             Lahore Qalandars
# 2                      Ireland
# 3                      England
# 4               Gujarat Titans
# 5                Karachi Kings
# 6                      England
# 7            Quetta Gladiators
# 8     United States of America
# 9                  West Indies
#
#                                                venue match_id outcome.result  \
# 0  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  1473503            NaN
# 1                            Gaddafi Stadium, Lahore  1475270            NaN
# 2                              Castle Avenue, Dublin  1472512      no result
# 3                                County Ground, Hove  1448392            NaN
# 4                   Narendra Modi Stadium, Ahmedabad  1473502            NaN
# 5                            Gaddafi Stadium, Lahore  1475269            NaN
# 6                     St Lawrence Ground, Canterbury  1448391            NaN
# 7                            Gaddafi Stadium, Lahore  1475268            NaN
# 8  Central Broward Regional Park Stadium Turf Gro...  1482566            tie
# 9                              Castle Avenue, Dublin  1472511            NaN
#
#   outcome.eliminator
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8               Oman
# 9                NaN

# %%
df["dates"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### **Seasons**

# %%
df["season"].unique()
# Out:
# array(['2025', '2024/25', '2024', '2023/24', '2023', '2022/23', '2022',
#        '2021/22', '2021', '2020/21', '2020', '2019/20', '2019', '2018/19',
#        '2018', '2017/18', '2017', '2016/17', '2016', '2015/16', '2015',
#        '2014/15', '2014', '2013/14', '2013', '2012/13', '2012', '2011/12',
#        '2011', '2010/11', '2010', '2009/10', '2009', '2008/09', '2008',
#        '2007/08', '2007', '2006/07', '2006', '2005/06', '2005', '2004/05',
#        '2004', '2003/04', '2003', '2002/03', '2001/02'], dtype=object)

# %%
df["season"] = df["dates"].dt.year

# %%
df["season"].unique()
# Out:
# array([2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015,
#        2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004,
#        2003, 2002, 2001], dtype=int32)

# %% [markdown]
# ### **Create team columns**

# %%
# Splitting the teams into team1 and team2 columns
teams = df['teams'].str.strip("[]").str.replace("'", "").str.split(', ', expand=True)
df['team1'] = teams[0]
df['team2'] = teams[1]

# Dropping the original 'teams' column
df.drop('teams', axis=1, inplace=True)

df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#         city      dates                         event.name  gender match_type  \
# 0    Lucknow 2025-05-23              Indian Premier League    male        T20
# 1     Lahore 2025-05-23              Pakistan Super League    male        T20
# 2     Dublin 2025-05-23        West Indies tour of Ireland    male        ODI
# 3   Brighton 2025-05-23  West Indies Women tour of England  female        T20
# 4  Ahmedabad 2025-05-22              Indian Premier League    male        T20
#
#          outcome.winner  season toss.decision                  toss.winner  \
# 0   Sunrisers Hyderabad    2025         field  Royal Challengers Bengaluru
# 1      Lahore Qalandars    2025           bat             Lahore Qalandars
# 2                   NaN    2025         field                      Ireland
# 3               England    2025         field                      England
# 4  Lucknow Super Giants    2025         field               Gujarat Titans
#
#                                                venue match_id outcome.result  \
# 0  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  1473503            NaN
# 1                            Gaddafi Stadium, Lahore  1475270            NaN
# 2                              Castle Avenue, Dublin  1472512      no result
# 3                                County Ground, Hove  1448392            NaN
# 4                   Narendra Modi Stadium, Ahmedabad  1473502            NaN
#
#   outcome.eliminator                 team1                        team2
# 0                NaN   Sunrisers Hyderabad  Royal Challengers Bengaluru
# 1                NaN      Lahore Qalandars             Islamabad United
# 2                NaN           West Indies                      Ireland
# 3                NaN           West Indies                      England
# 4                NaN  Lucknow Super Giants               Gujarat Titans

# %%
df.columns
# Out:
# Index(['city', 'dates', 'event.name', 'gender', 'match_type', 'outcome.winner',
#        'season', 'toss.decision', 'toss.winner', 'venue', 'match_id',
#        'outcome.result', 'outcome.eliminator', 'team1', 'team2'],
#       dtype='object')

# %% [markdown]
# ### **Check Unique Values & Clean the Data**

# %%
print("No of Teams:",df["team1"].nunique())
df["team1"].unique()[:10]
# Out:
# No of Teams: 355
# array(['Sunrisers Hyderabad', 'Lahore Qalandars', 'West Indies',
#        'Lucknow Super Giants', 'Karachi Kings', 'Quetta Gladiators',
#        'Oman', 'Ireland', 'Bangladesh', 'Mumbai Indians'], dtype=object)

# %%
print("No of Teams:",df["team1"].nunique())
df["team2"].unique()[:10]
# Out:
# No of Teams: 355
# array(['Royal Challengers Bengaluru', 'Islamabad United', 'Ireland',
#        'England', 'Gujarat Titans', 'Lahore Qalandars',
#        'United States of America', 'West Indies', 'United Arab Emirates',
#        'Delhi Capitals'], dtype=object)

# %%
print("No of Outcomes:",df["team1"].nunique())
df["outcome.winner"].unique()[:10]
# Out:
# No of Outcomes: 355
# array(['Sunrisers Hyderabad', 'Lahore Qalandars', nan, 'England',
#        'Lucknow Super Giants', 'Quetta Gladiators', 'Ireland',
#        'United Arab Emirates', 'Mumbai Indians', 'Thailand'], dtype=object)

# %%
print("Toss Decisions:",df["toss.decision"].nunique())
df["toss.decision"].unique()
# Out:
# Toss Decisions: 2
# array(['field', 'bat'], dtype=object)

# %%
print("Venues: ", df["venue"].nunique())
sorted(df["venue"].unique())[:10]
# Out:
# Venues:  838
# [' Emerald Heights International School Ground',
#  '7he Sevens Stadium, Dubai',
#  'ACA Stadium, Barsapara',
#  'ACA Stadium,Mangalagiri',
#  'AMI Stadium',
#  'Abhimanyu Cricket Academy, Dehradun',
#  'Abu Dhabi Oval 1',
#  'Abu Dhabi Oval 2',
#  'Achimota Senior Secondary School A Field, Accra',
#  'Achimota Senior Secondary School B Field, Accra']

# %%
df["match_type"].unique()
# Out:
# array(['T20', 'ODI', 'ODM', 'MDM', 'Test', 'IT20'], dtype=object)

# %%
# Display the updated DataFrame
print("Venues: ", df["venue"].nunique())
df[:5]
# Out:
# Venues:  838
#         city      dates                         event.name  gender match_type  \
# 0    Lucknow 2025-05-23              Indian Premier League    male        T20
# 1     Lahore 2025-05-23              Pakistan Super League    male        T20
# 2     Dublin 2025-05-23        West Indies tour of Ireland    male        ODI
# 3   Brighton 2025-05-23  West Indies Women tour of England  female        T20
# 4  Ahmedabad 2025-05-22              Indian Premier League    male        T20
#
#          outcome.winner  season toss.decision                  toss.winner  \
# 0   Sunrisers Hyderabad    2025         field  Royal Challengers Bengaluru
# 1      Lahore Qalandars    2025           bat             Lahore Qalandars
# 2                   NaN    2025         field                      Ireland
# 3               England    2025         field                      England
# 4  Lucknow Super Giants    2025         field               Gujarat Titans
#
#                                                venue match_id outcome.result  \
# 0  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  1473503            NaN
# 1                            Gaddafi Stadium, Lahore  1475270            NaN
# 2                              Castle Avenue, Dublin  1472512      no result
# 3                                County Ground, Hove  1448392            NaN
# 4                   Narendra Modi Stadium, Ahmedabad  1473502            NaN
#
#   outcome.eliminator                 team1                        team2
# 0                NaN   Sunrisers Hyderabad  Royal Challengers Bengaluru
# 1                NaN      Lahore Qalandars             Islamabad United
# 2                NaN           West Indies                      Ireland
# 3                NaN           West Indies                      England
# 4                NaN  Lucknow Super Giants               Gujarat Titans

# %%
df.columns
# Out:
# Index(['city', 'dates', 'event.name', 'gender', 'match_type', 'outcome.winner',
#        'season', 'toss.decision', 'toss.winner', 'venue', 'match_id',
#        'outcome.result', 'outcome.eliminator', 'team1', 'team2'],
#       dtype='object')

# %%
df = df[['match_id','season', 'dates','event.name', 'gender','match_type', 'team1', 'team2', 'toss.winner','toss.decision',  'outcome.winner', 'outcome.result', 'outcome.eliminator', 'venue', "city"]]

# %%
df.columns = ['match_id', 'season', 'match_date', 'event_name', 'gender', 'match_type', 'team1', 'team2','toss_winner', 'toss_decision', 'winner', 'outcome_result', 'outcome_eliminator','ground', 'city' ]

# %%
df.isnull().sum()
# Out:
# match_id                  0
# season                    0
# match_date                0
# event_name               89
# gender                    0
# match_type                0
# team1                     0
# team2                     0
# toss_winner               0
# toss_decision             0
# winner                 1414
# outcome_result        17494
# outcome_eliminator    18814
# ground                    0
# city                   1649
# dtype: int64

# %% [markdown]
# ### **Winner**

# %%
df[df['winner'].isnull()]
# Out:
#       match_id  season match_date  \
# 2      1472512    2025 2025-05-23
# 8      1482566    2025 2025-05-21
# 18     1461915    2025 2025-05-19
# 52     1462369    2025 2025-05-14
# 62     1483767    2025 2025-05-12
# ...        ...     ...        ...
# 18851    65273    2003 2003-03-04
# 18854    65272    2003 2003-03-03
# 18864    67517    2003 2003-02-25
# 18875    65249    2003 2003-02-18
# 18907    63963    2001 2001-12-23
#
#                                             event_name  gender match_type  \
# 2                          West Indies tour of Ireland    male        ODI
# 8                 ICC Men's Cricket World Cup League 2    male        ODI
# 18                                 County Championship    male        MDM
# 52                             ECB Women's One-Day Cup  female        ODM
# 62     ICC Women's T20 World Cup Asia Region Qualifier  female        T20
# ...                                                ...     ...        ...
# 18851                                    ICC World Cup    male        ODI
# 18854                                    ICC World Cup    male        ODI
# 18864                  England Women tour of Australia  female       Test
# 18875                                    ICC World Cup    male        ODI
# 18907                            England tour of India    male       Test
#
#              team1                     team2               toss_winner  \
# 2      West Indies                   Ireland                   Ireland
# 8             Oman  United States of America  United States of America
# 18      Lancashire                Derbyshire                Derbyshire
# 52       The Blaze                    Surrey                    Surrey
# 62         Bahrain                 Hong Kong                   Bahrain
# ...            ...                       ...                       ...
# 18851     Pakistan                  Zimbabwe                  Pakistan
# 18854    Sri Lanka              South Africa                 Sri Lanka
# 18864    Australia                   England                   England
# 18875  West Indies                Bangladesh                Bangladesh
# 18907      England                     India                   England
#
#       toss_decision winner outcome_result outcome_eliminator  \
# 2             field    NaN      no result                NaN
# 8             field    NaN            tie               Oman
# 18            field    NaN           draw                NaN
# 52            field    NaN            tie                NaN
# 62              bat    NaN      no result                NaN
# ...             ...    ...            ...                ...
# 18851           bat    NaN      no result                NaN
# 18854           bat    NaN            tie                NaN
# 18864         field    NaN           draw                NaN
# 18875         field    NaN      no result                NaN
# 18907           bat    NaN           draw                NaN
#
#                                                   ground        city
# 2                                  Castle Avenue, Dublin      Dublin
# 8      Central Broward Regional Park Stadium Turf Gro...  Lauderhill
# 18                              Old Trafford, Manchester  Manchester
# 52                 Kent County Cricket Ground, Beckenham   Beckenham
# 62                      Terdthai Cricket Ground, Bangkok     Bangkok
# ...                                                  ...         ...
# 18851                       Queens Sports Club, Bulawayo    Bulawayo
# 18854                                  Kingsmead, Durban      Durban
# 18864                             Bankstown Oval, Sydney      Sydney
# 18875                           Willowmoore Park, Benoni      Benoni
# 18907                   M Chinnaswamy Stadium, Bangalore   Bengaluru
#
# [1414 rows x 15 columns]

# %%
# Check if "winner" column is null, and if so, fill it with values from "outcome_eliminator"
df["winner"] = df["winner"].fillna(df["outcome_eliminator"])

# If "outcome_eliminator" is also null, fill "winner" with values from "outcome_result"
df["winner"] = df["winner"].fillna(df["outcome_result"])

df.drop(columns=["outcome_result", "outcome_eliminator"], inplace=True)

# %%
df[df['winner'].isnull()]
# Out:
# Empty DataFrame
# Columns: [match_id, season, match_date, event_name, gender, match_type, team1, team2, toss_winner, toss_decision, winner, ground, city]
# Index: []

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#       match_id  season match_date                         event_name  gender  \
# 0      1473503    2025 2025-05-23              Indian Premier League    male
# 1      1475270    2025 2025-05-23              Pakistan Super League    male
# 2      1472512    2025 2025-05-23        West Indies tour of Ireland    male
# 3      1448392    2025 2025-05-23  West Indies Women tour of England  female
# 4      1473502    2025 2025-05-22              Indian Premier League    male
# ...        ...     ...        ...                                ...     ...
# 18903    64815    2003 2003-01-01          India tour of New Zealand    male
# 18904    64012    2002 2002-12-30          England tour of Australia    male
# 18905    64022    2002 2002-12-29      Pakistan tour of South Africa    male
# 18906    64814    2002 2002-12-29          India tour of New Zealand    male
# 18907    63963    2001 2001-12-23              England tour of India    male
#
#       match_type                 team1                        team2  \
# 0            T20   Sunrisers Hyderabad  Royal Challengers Bengaluru
# 1            T20      Lahore Qalandars             Islamabad United
# 2            ODI           West Indies                      Ireland
# 3            T20           West Indies                      England
# 4            T20  Lucknow Super Giants               Gujarat Titans
# ...          ...                   ...                          ...
# 18903        ODI                 India                  New Zealand
# 18904       Test             Australia                      England
# 18905       Test          South Africa                     Pakistan
# 18906        ODI           New Zealand                        India
# 18907       Test               England                        India
#
#                        toss_winner toss_decision                winner  \
# 0      Royal Challengers Bengaluru         field   Sunrisers Hyderabad
# 1                 Lahore Qalandars           bat      Lahore Qalandars
# 2                          Ireland         field             no result
# 3                          England         field               England
# 4                   Gujarat Titans         field  Lucknow Super Giants
# ...                            ...           ...                   ...
# 18903                        India           bat           New Zealand
# 18904                    Australia           bat             Australia
# 18905                     Pakistan         field          South Africa
# 18906                        India         field           New Zealand
# 18907                      England           bat                  draw
#
#                                                   ground          city
# 0      Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...       Lucknow
# 1                                Gaddafi Stadium, Lahore        Lahore
# 2                                  Castle Avenue, Dublin        Dublin
# 3                                    County Ground, Hove      Brighton
# 4                       Narendra Modi Stadium, Ahmedabad     Ahmedabad
# ...                                                  ...           ...
# 18903                         Jade Stadium, Christchurch  Christchurch
# 18904                           Melbourne Cricket Ground     Melbourne
# 18905                                  Kingsmead, Durban        Durban
# 18906                                McLean Park, Napier        Napier
# 18907                   M Chinnaswamy Stadium, Bangalore     Bengaluru
#
# [18908 rows x 13 columns]

# %% [markdown]
# ### **Cleaning Ground Name**

# %%
df[df["ground"].isnull()]
# Out:
# Empty DataFrame
# Columns: [match_id, season, match_date, event_name, gender, match_type, team1, team2, toss_winner, toss_decision, winner, ground, city]
# Index: []

# %%
df[df["city"].isnull()]
# Out:
#       match_id  season match_date                  event_name gender  \
# 2589   1391925    2024 2024-03-27              Plunket Shield   male
# 2590   1391926    2024 2024-03-27              Plunket Shield   male
# 2592   1391924    2024 2024-03-26              Plunket Shield   male
# 2613   1391921    2024 2024-03-19              Plunket Shield   male
# 2614   1391923    2024 2024-03-19              Plunket Shield   male
# ...        ...     ...        ...                         ...    ...
# 18610   217481    2005 2005-08-29  Videocon Triangular Series   male
# 18617   214852    2005 2005-08-02              Indian Oil Cup   male
# 18618   214742    2005 2005-07-31              Indian Oil Cup   male
# 18655    65666    2005 2005-02-04                   VB Series   male
# 18662    65662    2005 2005-01-26                   VB Series   male
#
#       match_type               team1                 team2  \
# 2589         MDM  Northern Districts  Wellington Firebirds
# 2590         MDM       Central Stags           Otago Volts
# 2592         MDM       Auckland Aces            Canterbury
# 2613         MDM       Central Stags         Auckland Aces
# 2614         MDM          Canterbury    Northern Districts
# ...          ...                 ...                   ...
# 18610        ODI               India              Zimbabwe
# 18617        ODI           Sri Lanka           West Indies
# 18618        ODI         West Indies                 India
# 18655        ODI           Australia              Pakistan
# 18662        ODI           Australia           West Indies
#
#                 toss_winner toss_decision         winner  \
# 2589   Wellington Firebirds           bat           draw
# 2590          Central Stags         field  Central Stags
# 2592             Canterbury         field     Canterbury
# 2613          Central Stags         field  Auckland Aces
# 2614             Canterbury         field     Canterbury
# ...                     ...           ...            ...
# 18610              Zimbabwe         field          India
# 18617             Sri Lanka           bat      Sri Lanka
# 18618           West Indies           bat          India
# 18655             Australia           bat      Australia
# 18662             Australia           bat      Australia
#
#                                        ground city
# 2589                              Seddon Park  NaN
# 2590                              McLean Park  NaN
# 2592             Kennards Hire Community Oval  NaN
# 2613                              McLean Park  NaN
# 2614                           Mainpower Oval  NaN
# ...                                       ...  ...
# 18610                      Harare Sports Club  NaN
# 18617  Rangiri Dambulla International Stadium  NaN
# 18618  Rangiri Dambulla International Stadium  NaN
# 18655                Melbourne Cricket Ground  NaN
# 18662                           Adelaide Oval  NaN
#
# [1649 rows x 13 columns]

# %%
# Fill Null Values with ''
df['city'] = df['city'].fillna('')

# Concatenate 'ground' and 'city' columns
df.loc[:, 'ground'] = df['ground'] + "," + df['city']

# Drop the 'city' column
df = df.drop(columns="city")

# Remove any leading or trailing commas and spaces
df['ground'] = df['ground'].str.strip(', ')

# %%
def clean_ground_name(ground):
    if isinstance(ground, str):
        parts = ground.rsplit(',', 1)  # Split by the last comma
        if len(parts) == 2 and parts[0].endswith(parts[1]):
            return parts[0]
    return ground

def add_space_after_last_comma(value):
    if isinstance(value, str):
        last_comma_index = value.rfind(',')
        if last_comma_index != -1:
            value = value[:last_comma_index + 1] + ' ' + value[last_comma_index + 1:].strip()
    return value


# Apply the function to the 'ground' column
df['ground'] = df['ground'].apply(clean_ground_name)
df['ground'] = df['ground'].apply(add_space_after_last_comma)

# Display the modified DataFrame
df[:10]
# Out:
#   match_id  season match_date                            event_name  gender  \
# 0  1473503    2025 2025-05-23                 Indian Premier League    male
# 1  1475270    2025 2025-05-23                 Pakistan Super League    male
# 2  1472512    2025 2025-05-23           West Indies tour of Ireland    male
# 3  1448392    2025 2025-05-23     West Indies Women tour of England  female
# 4  1473502    2025 2025-05-22                 Indian Premier League    male
# 5  1475269    2025 2025-05-22                 Pakistan Super League    male
# 6  1448391    2025 2025-05-21     West Indies Women tour of England  female
# 7  1475268    2025 2025-05-21                 Pakistan Super League    male
# 8  1482566    2025 2025-05-21  ICC Men's Cricket World Cup League 2    male
# 9  1472511    2025 2025-05-21           West Indies tour of Ireland    male
#
#   match_type                 team1                        team2  \
# 0        T20   Sunrisers Hyderabad  Royal Challengers Bengaluru
# 1        T20      Lahore Qalandars             Islamabad United
# 2        ODI           West Indies                      Ireland
# 3        T20           West Indies                      England
# 4        T20  Lucknow Super Giants               Gujarat Titans
# 5        T20         Karachi Kings             Lahore Qalandars
# 6        T20           West Indies                      England
# 7        T20     Quetta Gladiators             Islamabad United
# 8        ODI                  Oman     United States of America
# 9        ODI               Ireland                  West Indies
#
#                    toss_winner toss_decision                winner  \
# 0  Royal Challengers Bengaluru         field   Sunrisers Hyderabad
# 1             Lahore Qalandars           bat      Lahore Qalandars
# 2                      Ireland         field             no result
# 3                      England         field               England
# 4               Gujarat Titans         field  Lucknow Super Giants
# 5                Karachi Kings           bat      Lahore Qalandars
# 6                      England         field               England
# 7            Quetta Gladiators           bat     Quetta Gladiators
# 8     United States of America         field                  Oman
# 9                  West Indies         field               Ireland
#
#                                               ground
# 0  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 1                            Gaddafi Stadium, Lahore
# 2                              Castle Avenue, Dublin
# 3                      County Ground, Hove, Brighton
# 4                   Narendra Modi Stadium, Ahmedabad
# 5                            Gaddafi Stadium, Lahore
# 6                     St Lawrence Ground, Canterbury
# 7                            Gaddafi Stadium, Lahore
# 8  Central Broward Regional Park Stadium Turf Gro...
# 9                              Castle Avenue, Dublin

# %%
# Sort the values in the 'ground' column and drop duplicates
ground_sorted = df['ground'].sort_values().drop_duplicates()

# Define the path to save the CSV file
output_path = r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\grounds.csv"

# Save the Series to a CSV file
ground_sorted.to_csv(output_path, index=False)

# %% [markdown]
# ### **Replacing the Neccesary Features**

# %% [markdown]
# #### **Grounds**

# %%
replacement1 = {"Adelaide Oval" : "Adelaide Oval, Adelaide", 
                "Andhra Cricket Association-Visakhapatnam District Cricket Association Stadium, Visakhapatnam" : "Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam", # YSR Stadium
                "Dr. Y.S. Rajasekhara Reddy ACA VDCA Cricket Stadium" : "Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam",
                "Al Amerat Cricket Ground Oman Cricket (Ministry Turf 1)" : "Al Amerat Cricket Ground Oman Cricket (Ministry Turf 1), Al Amarat",
                "Al Amerat Cricket Ground Oman Cricket (Ministry Turf 2)" : "Al Amerat Cricket Ground Oman Cricket (Ministry Turf 2), Al Amarat",
                "Antigua Recreation Ground, St John's" : "Antigua Recreation Ground, St John's, Antigua, St John's",
                "Antigua Recreation Ground, St John's, Antigua" : "Antigua Recreation Ground, St John's, Antigua, St John's",
                "Arnos Vale Ground, Kingstown" : "Arnos Vale Ground, Kingstown, St Vincent, Kingstown",
                "Arnos Vale Ground, Kingstown, St Vincent" : "Arnos Vale Ground, Kingstown, St Vincent, Kingstown",
                "Arun Jaitley Stadium" : "Arun Jaitley Stadium, Delhi", "Arundel Castle Cricket Club Ground" : "Arundel Castle Cricket Club Ground, Arundel",
                "Barabati Stadium" : "Barabati Stadium, Cuttack","Bay Oval" : "Bay Oval, Mount Maunganui",
                "Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium" : "Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow",
                "Bharat Ratna Shri Atal Bihari Vajpai Ekana Cricket Stadium, Lucknow": "Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow",
                "Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium B" : "Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow" ,
                "Bready Cricket Club, Magheramason, Bready": "Bready Cricket Club, Magheramason, Londonderry", 
                "Brian Lara Stadium, Tarouba, Trinidad" : "Brian Lara Stadium, Tarouba, Trinidad, Tarouba",
                "Brisbane Cricket Ground, Brisbane" : "Brisbane Cricket Ground, Woolloongabba, Brisbane",
                "Bulawayo Athletic Club" : "Bulawayo Athletic Club, Bulawayo","Boland Park, Paarl" : "Boland Bank Park, Paarl","Bready, Derry" : "Bready Cricket Club, Magheramason, Londonderry",
                "Carrara Oval" : "Carrara Oval, Carrara","Colin Maiden Park" : "Colin Maiden Park, Auckland","Coolidge Cricket Ground, Antigua" : "Coolidge Cricket Ground, Antigua, Coolidge",
                "County Ground, Hove" : "County Ground, Hove, Brighton","Casey Fields No 4, Melbourne" : "Casey Fields No. 4, Melbourne",
                "Daren Sammy National Cricket Stadium, Gros Islet, St Lucia, Gros Islet" : "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Darren Sammy National Cricket Stadium, St Lucia, Gros Islet" : "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Daren Sammy National Cricket Stadium, Gros Islet" : "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Daren Sammy National Cricket Stadium, Gros Islet, St Lucia, Gros Islet" : "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Daren Sammy National Cricket Stadium, Gros Islet, St Lucia" : "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Daren Sammy National Cricket Stadium, St Lucia, Gros Islet" : "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia": "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Dr DY Patil Sports Academy, Mumbai" : "Dr DY Patil Sports Academy, Mumbai, Navi Mumbai", "Dubai International Cricket Stadium" : "Dubai International Cricket Stadium, Dubai", 
                "Dubai Sports City Cricket Stadium" : "Dubai International Cricket Stadium, Dubai",
                "Eden Gardens" : "Eden Gardens, Kolkata", "Eden Park" : "Eden Park, Auckland", "Entebbe Cricket Oval" : "Entebbe Cricket Oval, Entebbe", 
                "Edgbaston, Birmingham" : "Edgbaston Foundation Community Sports Ground, Birmingham", "Fitzherbert Park" : "Fitzherbert Park, Palmerston North", 
                "Gahanga International Cricket Stadium. Rwanda" : "Gahanga International Cricket Stadium, Rwanda, Kigali City",
                "Gahanga International Cricket Stadium. Rwanda, Kigali City" : "Gahanga International Cricket Stadium, Rwanda, Kigali City",
                "Galle International Stadium" : "Galle International Stadium, Galle", "Grainville, St Saviour" : "Grainville, St Saviour, Jersey, St Saviour",
                "Grange Cricket Club Ground, Raeburn Place, Edinburgh" : "Grange Cricket Club, Raeburn Place, Edinburgh",
                "Greenfield Stadium" : "Greenfield International Stadium, Thiruvananthapuram", "Hagley Oval" : "Hagley Oval, Christchurch","Harare Sports Club" : "Harare Sports Club, Harare" }

replacement2 = {"Himachal Pradesh Cricket Association Stadium, Dharamsala" : "Himachal Pradesh Cricket Association Stadium, Dharmasala",
                "Hong Kong Cricket Club" : "Hong Kong Cricket Club, Wong Nai Chung Gap", "Holkar Stadium" : "Holkar Cricket Stadium, Indore",
                "ICC Academy, Dubai" : "ICC Global Cricket Academy, Dubai","JSCA International Stadium Complex" : "JSCA International Stadium Complex, Ranchi",
                "Johor Cricket Academy Oval" : "Johor Cricket Academy Oval, Johor","Kensington Oval, Bridgetown": "Kensington Oval, Barbados, Bridgetown", 
                "Kensington Oval, Bridgetown, Barbados" : "Kensington Oval, Barbados, Bridgetown","Kensington Oval, Bridgetown, Barbados, Bridgetown" : "Kensington Oval, Barbados, Bridgetown",
                "Kinrara Oval, Kuala Lumpur" : "Kinrara Academy Oval, Kuala Lumpur", "Kyambogo Cricket Oval, Kampala" : "Kyambogo Cricket Ground, Kampala",
                "Lalbhai Contractor Stadium" : "Lalabhai Contractor Stadium, Surat", "M Chinnaswamy Stadium, Bangalore, Bengaluru" : "M Chinnaswamy Stadium, Bengaluru", 
                "M Chinnaswamy Stadium, Bangalore" : "M Chinnaswamy Stadium, Bengaluru","M.Chinnaswamy Stadium, Bengaluru" : "M Chinnaswamy Stadium, Bengaluru", 
                "MA Aziz Stadium, Chattogram" : "MA Aziz Stadium, Chittagong, Chattogram","MA Chidambaram Stadium, Chennai" : "MA Chidambaram Stadium, Chepauk, Chennai",
                "Mainpower Oval" : "Mainpower Oval, Rangiora","McLean Park" : "McLean Park, Napier", "Melbourne Cricket Ground" : "Melbourne Cricket Ground, Melbourne",
                "Mission Road Ground, Mong Kok, Hong Kong" : "Mission Road Ground, Mong Kok, Hong Kong, Mong Kok", "Moara Vlasiei Cricket Ground" : "Moara Vlasiei Cricket Ground, Ilfov County", 
                "Molyneux Park" : "Molyneux Park, Alexandra", "Multan Cricket Stadium" : "Multan Cricket Stadium, Multan",  
                "National Cricket Stadium, Grenada, St George's" : "National Cricket Stadium, St George's, Grenada", "National Cricket Stadium, St George's" : "National Cricket Stadium, St George's, Grenada",
                "National Cricket Stadium, St George's, Grenada, St George's" : "National Cricket Stadium, St George's, Grenada", "Nelson Park" : "Nelson Park, Napier",
                "Narendra Modi Stadium Ground 'A', Motera" : "Narendra Modi Stadium, Ahmedabad","Nehru Stadium, Poona, Pune": "Nehru Stadium, Pune",
                "Nehru Stadium" : "Nehru Stadium, Guwahati", "Old Hararians, Harare" : "Old Hararians Sports Club, Harare",
                "Pallekele International Cricket Stadium, Kandy" : "Pallekele International Cricket Stadium", "Pallekele International Cricket Stadium, Pallekele" : "Pallekele International Cricket Stadium",
                "Perth Stadium" : "Perth Stadium, Perth", "Providence Stadium, Guyana" : "Providence Stadium, Guyana, Providence", 
                "Punjab Cricket Association IS Bindra Stadium, Chandigarh" : "Punjab Cricket Association Stadium, Mohali, Chandigarh", 
                "Punjab Cricket Association IS Bindra Stadium, Mohali" : "Punjab Cricket Association Stadium, Mohali, Chandigarh",
                "Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh" : "Punjab Cricket Association Stadium, Mohali, Chandigarh",
                "Queen's Park Oval, Port of Spain": "Queen's Park Oval, Port of Spain, Trinidad","Queen's Park Oval, Port of Spain, Trinidad, Port of Spain": "Queen's Park Oval, Port of Spain, Trinidad",
                "Queen's Park" : "Queen's Park, Invercargill","Queen's Park Oval, Trinidad, Port of Spain": "Queen's Park Oval, Port of Spain, Trinidad", "Queenstown Events Centre" : "Queenstown Events Centre, Queenstown", 
                "R.Premadasa Stadium, Colombo" : "R.Premadasa Stadium, Khettarama, Colombo", "R Premadasa Stadium, Colombo" : "R.Premadasa Stadium, Khettarama, Colombo",
                "Rajiv Gandhi International Cricket Stadium, Dehradun, Dehra Dun" : "Rajiv Gandhi International Cricket Stadium, Dehradun"
                }

replacement3 = {"Rajiv Gandhi International Stadium, Hyderabad" : "Rajiv Gandhi International Stadium, Uppal, Hyderabad", "Rangiri Dambulla International Stadium" : "Rangiri Dambulla International Stadium, Dambulla", 
                "Rawalpindi Cricket Stadium" : "Rawalpindi Cricket Stadium, Rawalpindi","Reliance Cricket Stadium" : "Reliance Stadium, Vadodara", "Royal Chiangmai Golf Club" : "Royal Chiangmai Golf Club, Chiang Mai",
                "Sabina Park, Kingston, Jamaica, Kingston": "Sabina Park, Kingston, Jamaica" ,"Sabina Park, Jamaica, Kingston" : "Sabina Park, Kingston, Jamaica",
                "Sano International Cricket Ground" : "Sano International Cricket Ground, Sano", "Sardar Patel Stadium, Motera, Ahmedabad" : "Sardar Patel (Gujarat) Stadium, Motera, Ahmedabad",
                "Sardar Patel Stadium, Ahmedabad" : "Sardar Patel (Gujarat) Stadium, Motera, Ahmedabad", "Saurashtra Cricket Association Stadium" : "Saurashtra Cricket Association Stadium, Rajkot", 
                "Saxton Oval" : "Saxton Oval, Nelson", "Seddon Park" : "Seddon Park, Hamilton", "Shaheed Veer Narayan Singh International Stadium" : "Shaheed Veer Narayan Singh International Stadium, Raipur",
                "Sharjah Cricket Association Stadium" : "Sharjah Cricket Association Stadium, Sharjah", "Sharjah Cricket Stadium" : "Sharjah Cricket Association Stadium, Sharjah",
                "Sharjah Cricket Stadium, Sharjah" : "Sharjah Cricket Association Stadium, Sharjah",
                "Shere Bangla National Stadium, Dhaka" : "Shere Bangla National Stadium, Mirpur, Dhaka", "Shere Bangla National Stadium, Mirpur" : "Shere Bangla National Stadium, Mirpur, Dhaka", 
                "Simonds Stadium, South Geelong, Victoria" : "Simonds Stadium, South Geelong, Victoria, Geelong", "Singapore Cricket Club, Singapore" : "Singapore Cricket Club, Padang", 
                "Sher-e-Bangla National Cricket Stadium, Mirpur" : "Shere Bangla National Stadium, Mirpur, Dhaka", "Sinhalese Sports Club, Colombo" : "Sinhalese Sports Club Ground, Colombo", 
                "Sir Vivian Richards Stadium, Antigua, North Sound" : "Sir Vivian Richards Stadium, North Sound, Antigua", "Sir Vivian Richards Stadium, North Sound" : "Sir Vivian Richards Stadium, North Sound, Antigua",
                "Sir Vivian Richards Stadium, North Sound, Antigua, North Sound": "Sir Vivian Richards Stadium, North Sound, Antigua","Sportpark Westvliet, The Hague" : "Sportpark Westvliet, Voorburg, The Hague", 
                "Sportpark Westvliet, Voorburg" : "Sportpark Westvliet, Voorburg, The Hague", "Tafawa Balewa Square (TBS) Cricket Oval" : "Tafawa Balewa Square Cricket Oval, Lagos",
                "St George's Park, Gqeberha" : "St George's Park, Port Elizabeth, Gqeberha", "St George's Park, Port Elizabeth" : "St George's Park, Port Elizabeth, Gqeberha",
                "Sydney Cricket Ground" : "Sydney Cricket Ground, Sydney", "Sydney Showground Stadium" : "Sydney Showground Stadium, Sydney", 
                "Sylhet International Cricket Stadium" : "Sylhet International Cricket Stadium, Academy Ground, Sylhet", 
                "Sylhet International Cricket Stadium, Sylhet" : "Sylhet International Cricket Stadium, Academy Ground, Sylhet", "Sylhet Stadium" : "Sylhet International Cricket Stadium, Academy Ground, Sylhet",
                "Takashinga Sports Club, Harare" : "Takashinga Sports Club, Highfield, Harare", "VRA Ground, Amstelveen" : "VRA Cricket Ground, Amstelveen", 
                "Vidarbha Cricket Association Stadium, Jamtha" : "Vidarbha Cricket Association Stadium, Jamtha, Nagpur", "Wanderers, Windhoek" : "Wanderers Cricket Ground, Windhoek",
                "Wankhede Stadium" : "Wankhede Stadium, Mumbai", "Warner Park, Basseterre": "Warner Park, Basseterre, St Kitts", "Warner Park, Basseterre, St Kitts, Basseterre": "Warner Park, Basseterre, St Kitts",
                "Warner Park, St Kitts, Basseterre": "Warner Park, Basseterre, St Kitts", "Vidarbha C.A. Ground, Nagpur" : "Vidarbha Cricket Association Stadium, Jamtha, Nagpur",
                "Vidarbha Cricket Association Ground, Nagpur" : "Vidarbha Cricket Association Stadium, Jamtha, Nagpur", "Zohur Ahmed Chowdhury Stadium, Chittagong" : "Zahur Ahmed Chowdhury Stadium, Chittagong, Chattogram",
                "Zahur Ahmed Chowdhury Stadium, Chattogram" : "Zahur Ahmed Chowdhury Stadium, Chittagong, Chattogram", "Zahur Ahmed Chowdhury Stadium, Chittagong" : "Zahur Ahmed Chowdhury Stadium, Chittagong, Chattogram",
                "Westpac Stadium" : "Westpac Stadium, Wellington", "Windsor Park, Roseau, Dominica" : "Windsor Park, Roseau, Dominica, Roseau"
                 }

replacements = {**replacement1, **replacement2, **replacement3}

df['ground'] = df['ground'].replace(replacements)

print("Grounds: ",df['ground'].nunique())
# Out:
# Grounds:  574

# %%
# Sort the values in the 'ground' column and drop duplicates
ground_sorted = df['ground'].sort_values().drop_duplicates()

# Define the path to save the CSV file
output_path = r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\cleaned_grounds.csv"

# Save the Series to a CSV file
ground_sorted.to_csv(output_path, index=False)

# %% [markdown]
# #### **Teams**

# %%
teams = set(df["team1"]).union(set(df["team2"]))
teams_df = pd.DataFrame(list(teams), columns=["team"]).sort_values(by="team").drop_duplicates(ignore_index=True)
teams_df.to_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\teams.csv")

# %%
teams_df
# Out:
#                         team
# 0     "Durbans Super Giants"
# 1    Abu Dhabi Knight Riders
# 2          Adelaide Strikers
# 3                  Africa XI
# 4                     Andhra
# ..                       ...
# 354           Worcestershire
# 355                Yorkshire
# 356       Yorkshire Diamonds
# 357                   Zambia
# 358                 Zimbabwe
#
# [359 rows x 1 columns]

# %%
import pandas as pd
import re

# Define a function to remove symbols
def remove_symbols(text):
    if pd.notna(text):  # Check if the value is not NaN
        # Remove all non-alphanumeric characters (except spaces)
        text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
        return text
    return text  # Return as is for NaN or None

# %%
# Apply the function to the 'team' column
teams_df["team"] = teams_df["team"].apply(remove_symbols)

# %%
teams_df
# Out:
#                         team
# 0       Durbans Super Giants
# 1    Abu Dhabi Knight Riders
# 2          Adelaide Strikers
# 3                  Africa XI
# 4                     Andhra
# ..                       ...
# 354           Worcestershire
# 355                Yorkshire
# 356       Yorkshire Diamonds
# 357                   Zambia
# 358                 Zimbabwe
#
# [359 rows x 1 columns]

# %%
ipl = df[df["event_name"] == "Indian Premier League"]
ipl_teams = set(ipl["team1"]).union(ipl['team2'])
ipl_teams
# Out:
# {'Chennai Super Kings',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Delhi Daredevils',
#  'Gujarat Lions',
#  'Gujarat Titans',
#  'Kings XI Punjab',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Lucknow Super Giants',
#  'Mumbai Indians',
#  'Pune Warriors',
#  'Punjab Kings',
#  'Rajasthan Royals',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiants',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bengaluru',
#  'Sunrisers Hyderabad'}

# %%
# Dictionary to map team name variations to abbreviations
team_name_mapping = {
    'Chennai Super Kings': 'CSK',
    'Deccan Chargers': 'SRH',
    'Delhi Capitals': 'DC',
    'Delhi Daredevils': 'DC',
    'Gujarat Lions': 'GL',
    'Gujarat Titans': 'GT',
    'Kings XI Punjab': 'PBKS',
    'Kochi Tuskers Kerala': 'KTK',
    'Kolkata Knight Riders': 'KKR',
    'Lucknow Super Giants': 'LSG',
    'Mumbai Indians': 'MI',
    'Pune Warriors': 'PW',
    'Punjab Kings': 'PBKS',
    'Rajasthan Royals': 'RR',
    'Rising Pune Supergiant': 'RPS',
    'Rising Pune Supergiants': 'RPS',
    'Royal Challengers Bangalore': 'RCB',
    'Royal Challengers Bengaluru': 'RCB',
    'Sunrisers Hyderabad': 'SRH',
    '"Durbans Super Giants"': "Durbans Super Giants",
    "United States Of America" : "USA"
}

# Apply the mapping to team1, team2, toss_winner, and winner columns
df['team1'] = df['team1'].replace(team_name_mapping)
df['team2'] = df['team2'].replace(team_name_mapping)
df["toss_winner"] = df['toss_winner'].replace(team_name_mapping)
df['winner'] = df['winner'].replace(team_name_mapping)

# %%
ipl = df[df["event_name"] == "Indian Premier League"]
ipl_teams = set(ipl["team1"]).union(ipl['team2'])
ipl_teams
# Out:
# {'CSK',
#  'DC',
#  'GL',
#  'GT',
#  'KKR',
#  'KTK',
#  'LSG',
#  'MI',
#  'PBKS',
#  'PW',
#  'RCB',
#  'RPS',
#  'RR',
#  'SRH'}

# %% [markdown]
# ### **Event**

# %%
replacements = {
    "NatWest T20 Blast": "Vitality Blast",
    "HRV Twenty20": "Super Smash",
    "HRV Cup": "Super Smash",
    "MiWAY T20 Challenge": "CSA T20 Challenge",
    "Ram Slam T20 Challenge": "CSA T20 Challenge", 
}


df["event_name"] = df["event_name"].replace(replacements, regex=True)

# %%
df['event_name'] = df['event_name'].replace("Indian Premier League","IPL", regex=True)

# %%
df[:10]
# Out:
#   match_id  season match_date                            event_name  gender  \
# 0  1473503    2025 2025-05-23                                   IPL    male
# 1  1475270    2025 2025-05-23                 Pakistan Super League    male
# 2  1472512    2025 2025-05-23           West Indies tour of Ireland    male
# 3  1448392    2025 2025-05-23     West Indies Women tour of England  female
# 4  1473502    2025 2025-05-22                                   IPL    male
# 5  1475269    2025 2025-05-22                 Pakistan Super League    male
# 6  1448391    2025 2025-05-21     West Indies Women tour of England  female
# 7  1475268    2025 2025-05-21                 Pakistan Super League    male
# 8  1482566    2025 2025-05-21  ICC Men's Cricket World Cup League 2    male
# 9  1472511    2025 2025-05-21           West Indies tour of Ireland    male
#
#   match_type              team1                     team2  \
# 0        T20                SRH                       RCB
# 1        T20   Lahore Qalandars          Islamabad United
# 2        ODI        West Indies                   Ireland
# 3        T20        West Indies                   England
# 4        T20                LSG                        GT
# 5        T20      Karachi Kings          Lahore Qalandars
# 6        T20        West Indies                   England
# 7        T20  Quetta Gladiators          Islamabad United
# 8        ODI               Oman  United States of America
# 9        ODI            Ireland               West Indies
#
#                 toss_winner toss_decision             winner  \
# 0                       RCB         field                SRH
# 1          Lahore Qalandars           bat   Lahore Qalandars
# 2                   Ireland         field          no result
# 3                   England         field            England
# 4                        GT         field                LSG
# 5             Karachi Kings           bat   Lahore Qalandars
# 6                   England         field            England
# 7         Quetta Gladiators           bat  Quetta Gladiators
# 8  United States of America         field               Oman
# 9               West Indies         field            Ireland
#
#                                               ground
# 0  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 1                            Gaddafi Stadium, Lahore
# 2                              Castle Avenue, Dublin
# 3                      County Ground, Hove, Brighton
# 4                   Narendra Modi Stadium, Ahmedabad
# 5                            Gaddafi Stadium, Lahore
# 6                     St Lawrence Ground, Canterbury
# 7                            Gaddafi Stadium, Lahore
# 8  Central Broward Regional Park Stadium Turf Gro...
# 9                              Castle Avenue, Dublin

# %%
df.to_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\summary_cleaned.csv")

# %%
df.head()
# Out:
#   match_id  season match_date                         event_name  gender  \
# 0  1473503    2025 2025-05-23                                IPL    male
# 1  1475270    2025 2025-05-23              Pakistan Super League    male
# 2  1472512    2025 2025-05-23        West Indies tour of Ireland    male
# 3  1448392    2025 2025-05-23  West Indies Women tour of England  female
# 4  1473502    2025 2025-05-22                                IPL    male
#
#   match_type             team1             team2       toss_winner  \
# 0        T20               SRH               RCB               RCB
# 1        T20  Lahore Qalandars  Islamabad United  Lahore Qalandars
# 2        ODI       West Indies           Ireland           Ireland
# 3        T20       West Indies           England           England
# 4        T20               LSG                GT                GT
#
#   toss_decision            winner  \
# 0         field               SRH
# 1           bat  Lahore Qalandars
# 2         field         no result
# 3         field           England
# 4         field               LSG
#
#                                               ground
# 0  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 1                            Gaddafi Stadium, Lahore
# 2                              Castle Avenue, Dublin
# 3                      County Ground, Hove, Brighton
# 4                   Narendra Modi Stadium, Ahmedabad

# %% [markdown]
# ### **Summary**

# %%
import pandas as pd
summary_df = pd.read_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\summary_cleaned.csv")
summary_df.drop(columns="Unnamed: 0", inplace=True)
summary_df
# Out:
#       match_id  season  match_date                         event_name  gender  \
# 0      1473503    2025  2025-05-23                                IPL    male
# 1      1475270    2025  2025-05-23              Pakistan Super League    male
# 2      1472512    2025  2025-05-23        West Indies tour of Ireland    male
# 3      1448392    2025  2025-05-23  West Indies Women tour of England  female
# 4      1473502    2025  2025-05-22                                IPL    male
# ...        ...     ...         ...                                ...     ...
# 18903    64815    2003  2003-01-01          India tour of New Zealand    male
# 18904    64012    2002  2002-12-30          England tour of Australia    male
# 18905    64022    2002  2002-12-29      Pakistan tour of South Africa    male
# 18906    64814    2002  2002-12-29          India tour of New Zealand    male
# 18907    63963    2001  2001-12-23              England tour of India    male
#
#       match_type             team1             team2       toss_winner  \
# 0            T20               SRH               RCB               RCB
# 1            T20  Lahore Qalandars  Islamabad United  Lahore Qalandars
# 2            ODI       West Indies           Ireland           Ireland
# 3            T20       West Indies           England           England
# 4            T20               LSG                GT                GT
# ...          ...               ...               ...               ...
# 18903        ODI             India       New Zealand             India
# 18904       Test         Australia           England         Australia
# 18905       Test      South Africa          Pakistan          Pakistan
# 18906        ODI       New Zealand             India             India
# 18907       Test           England             India           England
#
#       toss_decision            winner  \
# 0             field               SRH
# 1               bat  Lahore Qalandars
# 2             field         no result
# 3             field           England
# 4             field               LSG
# ...             ...               ...
# 18903           bat       New Zealand
# 18904           bat         Australia
# 18905         field      South Africa
# 18906         field       New Zealand
# 18907           bat              draw
#
#                                                   ground
# 0      Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 1                                Gaddafi Stadium, Lahore
# 2                                  Castle Avenue, Dublin
# 3                          County Ground, Hove, Brighton
# 4                       Narendra Modi Stadium, Ahmedabad
# ...                                                  ...
# 18903                         Jade Stadium, Christchurch
# 18904                Melbourne Cricket Ground, Melbourne
# 18905                                  Kingsmead, Durban
# 18906                                McLean Park, Napier
# 18907                   M Chinnaswamy Stadium, Bengaluru
#
# [18908 rows x 12 columns]

# %%
no_result_df = summary_df[(summary_df['winner'] != summary_df['team1']) & (summary_df['winner'] != summary_df['team2'])].reset_index(drop=True)
no_result_df
# Out:
#      match_id  season  match_date  \
# 0     1472512    2025  2025-05-23
# 1     1461915    2025  2025-05-19
# 2     1462369    2025  2025-05-14
# 3     1483767    2025  2025-05-12
# 4     1461845    2025  2025-05-12
# ...       ...     ...         ...
# 1329    65273    2003  2003-03-04
# 1330    65272    2003  2003-03-03
# 1331    67517    2003  2003-02-25
# 1332    65249    2003  2003-02-18
# 1333    63963    2001  2001-12-23
#
#                                            event_name  gender match_type  \
# 0                         West Indies tour of Ireland    male        ODI
# 1                                 County Championship    male        MDM
# 2                             ECB Women's One-Day Cup  female        ODM
# 3     ICC Women's T20 World Cup Asia Region Qualifier  female        T20
# 4                                 County Championship    male        MDM
# ...                                               ...     ...        ...
# 1329                                    ICC World Cup    male        ODI
# 1330                                    ICC World Cup    male        ODI
# 1331                  England Women tour of Australia  female       Test
# 1332                                    ICC World Cup    male        ODI
# 1333                            England tour of India    male       Test
#
#             team1         team2 toss_winner toss_decision     winner  \
# 0     West Indies       Ireland     Ireland         field  no result
# 1      Lancashire    Derbyshire  Derbyshire         field       draw
# 2       The Blaze        Surrey      Surrey         field        tie
# 3         Bahrain     Hong Kong     Bahrain           bat  no result
# 4       Yorkshire         Essex   Yorkshire           bat       draw
# ...           ...           ...         ...           ...        ...
# 1329     Pakistan      Zimbabwe    Pakistan           bat  no result
# 1330    Sri Lanka  South Africa   Sri Lanka           bat        tie
# 1331    Australia       England     England         field       draw
# 1332  West Indies    Bangladesh  Bangladesh         field  no result
# 1333      England         India     England           bat       draw
#
#                                      ground
# 0                     Castle Avenue, Dublin
# 1                  Old Trafford, Manchester
# 2     Kent County Cricket Ground, Beckenham
# 3          Terdthai Cricket Ground, Bangkok
# 4                 County Ground, Chelmsford
# ...                                     ...
# 1329           Queens Sports Club, Bulawayo
# 1330                      Kingsmead, Durban
# 1331                 Bankstown Oval, Sydney
# 1332               Willowmoore Park, Benoni
# 1333       M Chinnaswamy Stadium, Bengaluru
#
# [1334 rows x 12 columns]

# %%
no_result_df[no_result_df["event_name"] == "IPL"]
# Out:
#      match_id  season  match_date event_name gender match_type team1 team2  \
# 6     1473495    2025  2025-05-08        IPL   male        T20  PBKS    DC
# 10    1473492    2025  2025-05-05        IPL   male        T20    DC   SRH
# 14    1473481    2025  2025-04-26        IPL   male        T20  PBKS   KKR
# 278   1359519    2023  2023-05-03        IPL   male        T20   LSG   CSK
# 679   1178424    2019  2019-04-30        IPL   male        T20   RCB    RR
# 1034   829813    2015  2015-05-17        IPL   male        T20   RCB    DC
# 1045   829763    2015  2015-04-29        IPL   male        T20   RCB    RR
# 1208   501265    2011  2011-05-21        IPL   male        T20    DC    PW
#
#      toss_winner toss_decision     winner  \
# 6           PBKS           bat  no result
# 10           SRH         field  no result
# 14          PBKS           bat  no result
# 278          CSK         field  no result
# 679           RR         field  no result
# 1034         RCB         field  no result
# 1045          RR         field  no result
# 1208          DC           bat  no result
#
#                                                  ground
# 6     Himachal Pradesh Cricket Association Stadium, ...
# 10    Rajiv Gandhi International Stadium, Uppal, Hyd...
# 14                                Eden Gardens, Kolkata
# 278   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 679                    M Chinnaswamy Stadium, Bengaluru
# 1034                   M Chinnaswamy Stadium, Bengaluru
# 1045                   M Chinnaswamy Stadium, Bengaluru
# 1208                            Feroz Shah Kotla, Delhi

# %% [markdown]
# ### **Gender**

# %%
summary_df['gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# ### **Match type**

# %%
summary_df['match_type'].unique()
# Out:
# array(['T20', 'ODI', 'ODM', 'MDM', 'Test', 'IT20'], dtype=object)

# %%
summary_df['match_type'] = summary_df['match_type'].replace("IT20","T20",regex=False)

# %%
summary_df['match_type'].unique()
# Out:
# array(['T20', 'ODI', 'ODM', 'MDM', 'Test'], dtype=object)

# %%
summary_df["match_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
print("Length of Data Frame:", len(summary_df))
summary_df.to_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\male\summary_cleaned.csv")
summary_df.to_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\female\summary_cleaned.csv")
# Out:
# Length of Data Frame: 18908

# %%
male = summary_df[summary_df["gender"] == "male"]
female = summary_df[summary_df["gender"] == "female"]

# %%
male.to_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\male\male_summary_cleaned.csv")
female.to_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\female\female_summary_cleaned.csv")
match_types = summary_df["match_type"].drop_duplicates().reset_index(drop=True)
match_types.to_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\match_types.csv")

# %% [markdown]
# ### **T20's**

# %%
import pandas as pd
# Enter the Gender
gender = input("Enter Gender: ").lower()

summary_df = pd.read_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\{gender}_summary_cleaned.csv")
summary_df.drop(columns=["Unnamed: 0"], inplace=True)
summary_df
# Out:
#      match_id  season  match_date  \
# 0     1448392    2025  2025-05-23
# 1     1448391    2025  2025-05-21
# 2     1485778    2025  2025-05-20
# 3     1462374    2025  2025-05-20
# 4     1462373    2025  2025-05-19
# ...       ...     ...         ...
# 3511   271466    2007  2007-01-24
# 3512   271465    2007  2007-01-22
# 3513   225164    2006  2006-08-11
# 3514   216932    2005  2005-08-27
# 3515    67517    2003  2003-02-25
#
#                                            event_name  gender match_type  \
# 0                   West Indies Women tour of England  female        T20
# 1                   West Indies Women tour of England  female        T20
# 2     ICC Women's T20 World Cup Asia Region Qualifier  female        T20
# 3                             ECB Women's One-Day Cup  female        ODM
# 4                             ECB Women's One-Day Cup  female        ODM
# ...                                               ...     ...        ...
# 3511              Pakistan Women tour of South Africa  female        ODI
# 3512              Pakistan Women tour of South Africa  female        ODI
# 3513          India Women tour of Ireland and England  female       Test
# 3514                  Australia Women tour of England  female       Test
# 3515                  England Women tour of Australia  female       Test
#
#              team1         team2 toss_winner toss_decision        winner  \
# 0      West Indies       England     England         field       England
# 1      West Indies       England     England         field       England
# 2         Thailand         Nepal       Nepal         field      Thailand
# 3         Somerset     The Blaze   The Blaze         field     The Blaze
# 4       Lancashire        Durham      Durham         field    Lancashire
# ...            ...           ...         ...           ...           ...
# 3511      Pakistan  South Africa    Pakistan           bat  South Africa
# 3512  South Africa      Pakistan    Pakistan         field  South Africa
# 3513       England         India     England           bat          draw
# 3514     Australia       England     England         field       England
# 3515     Australia       England     England         field          draw
#
#                                   ground
# 0          County Ground, Hove, Brighton
# 1         St Lawrence Ground, Canterbury
# 2       Terdthai Cricket Ground, Bangkok
# 3        Haslegrave Ground, Loughborough
# 4                Stanley Park, Blackpool
# ...                                  ...
# 3511  Sinovich Park, Sinoville, Pretoria
# 3512                Harlequins, Pretoria
# 3513               Grace Road, Leicester
# 3514  County Ground, New Road, Worcester
# 3515              Bankstown Oval, Sydney
#
# [3516 rows x 12 columns]

# %%
t20 = summary_df[summary_df['match_type'] == "T20"].sort_values(by=["match_date","match_id"], ascending=False).reset_index(drop=True)
t20[:5]
# Out:
#   match_id  season  match_date  \
# 0  1448392    2025  2025-05-23
# 1  1448391    2025  2025-05-21
# 2  1485778    2025  2025-05-20
# 3  1483779    2025  2025-05-19
# 4  1483778    2025  2025-05-18
#
#                                         event_name  gender match_type  \
# 0                West Indies Women tour of England  female        T20
# 1                West Indies Women tour of England  female        T20
# 2  ICC Women's T20 World Cup Asia Region Qualifier  female        T20
# 3  ICC Women's T20 World Cup Asia Region Qualifier  female        T20
# 4  ICC Women's T20 World Cup Asia Region Qualifier  female        T20
#
#                   team1                 team2 toss_winner toss_decision  \
# 0           West Indies               England     England         field
# 1           West Indies               England     England         field
# 2              Thailand                 Nepal       Nepal         field
# 3  United Arab Emirates                 Nepal       Nepal         field
# 4              Thailand  United Arab Emirates    Thailand           bat
#
#      winner                            ground
# 0   England     County Ground, Hove, Brighton
# 1   England    St Lawrence Ground, Canterbury
# 2  Thailand  Terdthai Cricket Ground, Bangkok
# 3     Nepal  Terdthai Cricket Ground, Bangkok
# 4  Thailand  Terdthai Cricket Ground, Bangkok

# %%
t20.isnull().sum()
# Out:
# match_id         0
# season           0
# match_date       0
# event_name       4
# gender           0
# match_type       0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# ground           0
# dtype: int64

# %%
t20.to_csv(rf"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\T20_{gender}_match_summary_cleaned.csv")

# %% [markdown]
# ### **IT20's**

# %%
it20 = summary_df[summary_df['match_type'] == "IT20"].sort_values(by=["match_date","match_id"], ascending=False).reset_index(drop=True)
it20
# Out:
# Empty DataFrame
# Columns: [match_id, season, match_date, event_name, gender, match_type, team1, team2, toss_winner, toss_decision, winner, ground]
# Index: []

# %%
it20.isnull().sum()
# Out:
# match_id         0
# season           0
# match_date       0
# event_name       0
# gender           0
# match_type       0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# ground           0
# dtype: int64

# %%
it20.to_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\IT20_{gender}_match_summary_cleaned.csv")

# %% [markdown]
# ### **ODI's**

# %%
odi = summary_df[summary_df['match_type'] == "ODI"].sort_values(by=["match_date","match_id"], ascending=False).reset_index(drop=True)
odi
# Out:
#     match_id  season  match_date  \
# 0    1476986    2025  2025-05-11
# 1    1476985    2025  2025-05-09
# 2    1476984    2025  2025-05-07
# 3    1476983    2025  2025-05-04
# 4    1481713    2025  2025-05-03
# ..       ...     ...         ...
# 509   312295    2008  2008-02-22
# 510   312291    2008  2008-02-21
# 511   276226    2007  2007-03-05
# 512   271466    2007  2007-01-24
# 513   271465    2007  2007-01-22
#
#                                           event_name  gender match_type  \
# 0                   Sri Lanka Women's ODI Tri-Series  female        ODI
# 1                   Sri Lanka Women's ODI Tri-Series  female        ODI
# 2                   Sri Lanka Women's ODI Tri-Series  female        ODI
# 3                   Sri Lanka Women's ODI Tri-Series  female        ODI
# 4    Zimbabwe Women tour of United States of America  female        ODI
# ..                                               ...     ...        ...
# 509          ICC Women's World Cup Qualifying Series  female        ODI
# 510          ICC Women's World Cup Qualifying Series  female        ODI
# 511                      Women's Quadrangular Series  female        ODI
# 512              Pakistan Women tour of South Africa  female        ODI
# 513              Pakistan Women tour of South Africa  female        ODI
#
#             team1                     team2               toss_winner  \
# 0           India                 Sri Lanka                     India
# 1    South Africa                 Sri Lanka                 Sri Lanka
# 2           India              South Africa              South Africa
# 3           India                 Sri Lanka                 Sri Lanka
# 4        Zimbabwe  United States of America  United States of America
# ..            ...                       ...                       ...
# 509       Ireland              South Africa                   Ireland
# 510  South Africa               Netherlands              South Africa
# 511   New Zealand                 Australia               New Zealand
# 512      Pakistan              South Africa                  Pakistan
# 513  South Africa                  Pakistan                  Pakistan
#
#     toss_decision        winner                                    ground
# 0             bat         India  R.Premadasa Stadium, Khettarama, Colombo
# 1           field  South Africa  R.Premadasa Stadium, Khettarama, Colombo
# 2           field         India  R.Premadasa Stadium, Khettarama, Colombo
# 3           field     Sri Lanka  R.Premadasa Stadium, Khettarama, Colombo
# 4           field      Zimbabwe             Grand Prairie Stadium, Dallas
# ..            ...           ...                                       ...
# 509           bat  South Africa                 Stellenbosch University 1
# 510           bat  South Africa                 Stellenbosch University 1
# 511           bat     Australia  MA Chidambaram Stadium, Chepauk, Chennai
# 512           bat  South Africa        Sinovich Park, Sinoville, Pretoria
# 513         field  South Africa                      Harlequins, Pretoria
#
# [514 rows x 12 columns]

# %%
odi.isnull().sum()
# Out:
# match_id         0
# season           0
# match_date       0
# event_name       0
# gender           0
# match_type       0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# ground           0
# dtype: int64

# %%
odi.to_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\ODI_{gender}_match_summary_cleaned.csv")

# %% [markdown]
# ### **ODM's**

# %%
odm = summary_df[summary_df['match_type'] == "ODM"].sort_values(by=["match_date","match_id"], ascending=False).reset_index(drop=True)
odm
# Out:
#     match_id  season  match_date  \
# 0    1462374    2025  2025-05-20
# 1    1462373    2025  2025-05-19
# 2    1462372    2025  2025-05-19
# 3    1462371    2025  2025-05-19
# 4    1462370    2025  2025-05-14
# ..       ...     ...         ...
# 254  1073407    2017  2017-02-08
# 255  1073406    2017  2017-02-08
# 256  1073404    2017  2017-02-07
# 257  1073402    2017  2017-02-07
# 258  1033707    2016  2016-07-15
#
#                                             event_name  gender match_type  \
# 0                              ECB Women's One-Day Cup  female        ODM
# 1                              ECB Women's One-Day Cup  female        ODM
# 2                              ECB Women's One-Day Cup  female        ODM
# 3                              ECB Women's One-Day Cup  female        ODM
# 4                              ECB Women's One-Day Cup  female        ODM
# ..                                                 ...     ...        ...
# 254                    ICC Women's World Cup Qualifier  female        ODM
# 255                    ICC Women's World Cup Qualifier  female        ODM
# 256                    ICC Women's World Cup Qualifier  female        ODM
# 257                    ICC Women's World Cup Qualifier  female        ODM
# 258  ICC Women's World Cup Qualifying Series Europe...  female        ODM
#
#             team1             team2   toss_winner toss_decision        winner  \
# 0        Somerset         The Blaze     The Blaze         field     The Blaze
# 1      Lancashire            Durham        Durham         field    Lancashire
# 2    Warwickshire         Hampshire  Warwickshire           bat     Hampshire
# 3          Surrey             Essex         Essex         field        Surrey
# 4      Lancashire      Warwickshire    Lancashire           bat    Lancashire
# ..            ...               ...           ...           ...           ...
# 254      Scotland      South Africa      Scotland           bat  South Africa
# 255         India          Thailand      Thailand           bat         India
# 256    Bangladesh  Papua New Guinea    Bangladesh           bat    Bangladesh
# 257       Ireland          Zimbabwe      Zimbabwe         field       Ireland
# 258   Netherlands          Scotland   Netherlands           bat      Scotland
#
#                                                 ground
# 0                      Haslegrave Ground, Loughborough
# 1                              Stanley Park, Blackpool
# 2          Arundel Castle Cricket Club Ground, Arundel
# 3                            County Ground, Chelmsford
# 4    Edgbaston Foundation Community Sports Ground, ...
# ..                                                 ...
# 254     Mercantile Cricket Association Ground, Colombo
# 255                        Colombo Cricket Club Ground
# 256                        Colombo Cricket Club Ground
# 257     Mercantile Cricket Association Ground, Colombo
# 258                        Garon Park, Southend-on-Sea
#
# [259 rows x 12 columns]

# %%
odm.isnull().sum()
# Out:
# match_id         0
# season           0
# match_date       0
# event_name       0
# gender           0
# match_type       0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# ground           0
# dtype: int64

# %%
odm.to_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\ODM_{gender}_match_summary_cleaned.csv")

# %% [markdown]
# ### **MDM's**

# %%
mdm = summary_df[summary_df['match_type'] == "MDM"].sort_values(by=["match_date","match_id"], ascending=False).reset_index(drop=True)
mdm
# Out:
# Empty DataFrame
# Columns: [match_id, season, match_date, event_name, gender, match_type, team1, team2, toss_winner, toss_decision, winner, ground]
# Index: []

# %%
mdm.isnull().sum()
# Out:
# match_id         0
# season           0
# match_date       0
# event_name       0
# gender           0
# match_type       0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# ground           0
# dtype: int64

# %%
mdm.to_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\MDM_{gender}_match_summary_cleaned.csv")

# %% [markdown]
# ### **Test's**

# %%
test = summary_df[summary_df['match_type'] == "Test"].sort_values(by=["match_date","match_id"], ascending=False).reset_index(drop=True)
test
# Out:
#    match_id  season  match_date  \
# 0   1426629    2025  2025-02-01
# 1   1432231    2024  2024-12-17
# 2   1434290    2024  2024-07-01
# 3   1375875    2024  2024-02-17
# 4   1406077    2023  2023-12-24
# 5   1406076    2023  2023-12-16
# 6   1336073    2023  2023-06-26
# 7   1301327    2022  2022-06-30
# 8   1263571    2022  2022-01-30
# 9   1263620    2021  2021-10-03
# 10  1260093    2021  2021-06-19
# 11  1168025    2019  2019-07-21
# 12  1086066    2017  2017-11-12
# 13   798375    2015  2015-08-14
# 14   722387    2014  2014-08-16
# 15   593722    2013  2013-08-14
# 16   474625    2011  2011-01-25
# 17   383288    2009  2009-07-13
# 18   312450    2008  2008-02-18
# 19   225164    2006  2006-08-11
# 20   216932    2005  2005-08-27
# 21    67517    2003  2003-02-25
#
#                                          event_name  gender match_type  \
# 0                                     Women's Ashes  female       Test
# 1                England Women tour of South Africa  female       Test
# 2                  South Africa Women tour of India  female       Test
# 3              South Africa Women tour of Australia  female       Test
# 4                     Australia Women tour of India  female       Test
# 5                       England Women tour of India  female       Test
# 6                                     Women's Ashes  female       Test
# 7                South Africa Women tour of England  female       Test
# 8                                     Women's Ashes  female       Test
# 9                     India Women tour of Australia  female       Test
# 10                      India Women tour of England  female       Test
# 11                  Australia Women tour of England  female       Test
# 12                                    Women's Ashes  female       Test
# 13                                    Women's Ashes  female       Test
# 14                                              NaN  female       Test
# 15                                    Women's Ashes  female       Test
# 16                  England Women tour of Australia  female       Test
# 17                  Australia Women tour of England  female       Test
# 18  England Women tour of Australia and New Zealand  female       Test
# 19          India Women tour of Ireland and England  female       Test
# 20                  Australia Women tour of England  female       Test
# 21                  England Women tour of Australia  female       Test
#
#            team1         team2 toss_winner toss_decision     winner  \
# 0        England     Australia   Australia         field  Australia
# 1        England  South Africa     England           bat    England
# 2          India  South Africa       India           bat      India
# 3   South Africa     Australia   Australia         field  Australia
# 4      Australia         India   Australia           bat      India
# 5          India       England       India           bat      India
# 6      Australia       England   Australia           bat  Australia
# 7   South Africa       England     England         field       draw
# 8      Australia       England     England         field       draw
# 9          India     Australia   Australia         field       draw
# 10       England         India     England           bat       draw
# 11       England     Australia   Australia           bat       draw
# 12       England     Australia     England           bat       draw
# 13       England     Australia   Australia           bat  Australia
# 14       England         India       India         field      India
# 15       England     Australia   Australia           bat       draw
# 16       England     Australia     England           bat  Australia
# 17     Australia       England   Australia           bat       draw
# 18     Australia       England     England         field    England
# 19       England         India     England           bat       draw
# 20     Australia       England     England         field    England
# 21     Australia       England     England         field       draw
#
#                                                ground
# 0                 Melbourne Cricket Ground, Melbourne
# 1                         Mangaung Oval, Bloemfontein
# 2            MA Chidambaram Stadium, Chepauk, Chennai
# 3   Western Australia Cricket Association Ground, ...
# 4                            Wankhede Stadium, Mumbai
# 5     Dr DY Patil Sports Academy, Mumbai, Navi Mumbai
# 6                            Trent Bridge, Nottingham
# 7        The Cooper Associates County Ground, Taunton
# 8                               Manuka Oval, Canberra
# 9                               Carrara Oval, Carrara
# 10                             County Ground, Bristol
# 11       The Cooper Associates County Ground, Taunton
# 12                          North Sydney Oval, Sydney
# 13                     St Lawrence Ground, Canterbury
# 14                  Sir Paul Getty's Ground, Wormsley
# 15                  Sir Paul Getty's Ground, Wormsley
# 16                             Bankstown Oval, Sydney
# 17                 County Ground, New Road, Worcester
# 18                               Bradman Oval, Bowral
# 19                              Grace Road, Leicester
# 20                 County Ground, New Road, Worcester
# 21                             Bankstown Oval, Sydney

# %%
test.isnull().sum()
# Out:
# match_id         0
# season           0
# match_date       0
# event_name       1
# gender           0
# match_type       0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# ground           0
# dtype: int64

# %%
test.to_csv(rf"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\Test_{gender}_match_summary_cleaned.csv")
