# %%
import pandas as  pd
df = pd.read_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\match_summary.csv", low_memory=False)
#df.drop(columns="Unnamed: 0", inplace=True)
print("Length of Data Frame:", len(df))
df.head(1)
# Out:
# Length of Data Frame: 22559
#    balls_per_over       city           dates  \
# 0               6  Spinaceto  ['2024-06-13']
#
#                                           event.name  event.match_number  \
# 0  ICC Men's T20 World Cup Sub Regional Europe Qu...                13.0
#
#   event.group gender match_type  match_type_number officials.match_referees  \
# 0           B   male        T20             2673.0             ['G McCrea']
#
#    ... event.stage officials.tv_umpires outcome.by.innings  outcome.result  \
# 0  ...         NaN                  NaN                NaN             NaN
#
#    outcome.method event.sub_name bowl_out outcome.bowl_out outcome.eliminator  \
# 0             NaN            NaN      NaN              NaN                NaN
#
#   toss.uncontested
# 0              NaN
#
# [1 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['balls_per_over', 'city', 'dates', 'event.name', 'event.match_number',
#        'event.group', 'gender', 'match_type', 'match_type_number',
#        'officials.match_referees', 'officials.reserve_umpires',
#        'officials.umpires', 'outcome.winner', 'outcome.by.wickets', 'overs',
#        'player_of_match', 'season', 'team_type', 'teams', 'toss.decision',
#        'toss.winner', 'venue', 'match_id', 'outcome.by.runs', 'missing',
#        'event.stage', 'officials.tv_umpires', 'outcome.by.innings',
#        'outcome.result', 'outcome.method', 'event.sub_name', 'bowl_out',
#        'outcome.bowl_out', 'outcome.eliminator', 'toss.uncontested'],
#       dtype='object')

# %%
df.drop(columns=['balls_per_over','outcome.by.runs',"match_type_number", 'overs','outcome.by.innings','event.match_number','outcome.by.wickets', 'officials.umpires','outcome.method',  'missing',  
                 'officials.reserve_umpires', 'officials.match_referees',"team_type", 'bowl_out',"officials.tv_umpires","event.stage",'event.sub_name', "player_of_match",'event.stage', 'event.group','toss.uncontested',
                 'outcome.bowl_out'], inplace=True)

# %%
df.head()
# Out:
#         city           dates  \
# 0  Spinaceto  ['2024-06-13']
# 1       Rome  ['2024-06-13']
# 2  Spinaceto  ['2024-06-13']
# 3       Rome  ['2024-06-13']
# 4  Spinaceto  ['2024-06-15']
#
#                                           event.name gender match_type  \
# 0  ICC Men's T20 World Cup Sub Regional Europe Qu...   male        T20
# 1  ICC Men's T20 World Cup Sub Regional Europe Qu...   male        T20
# 2  ICC Men's T20 World Cup Sub Regional Europe Qu...   male        T20
# 3  ICC Men's T20 World Cup Sub Regional Europe Qu...   male        T20
# 4  ICC Men's T20 World Cup Sub Regional Europe Qu...   male        T20
#
#   outcome.winner season                          teams toss.decision  \
# 0        Romania   2024         ['Hungary', 'Romania']         field
# 1         France   2024       ['France', 'Luxembourg']           bat
# 2         Israel   2024         ['Portugal', 'Israel']           bat
# 3          Italy   2024            ['Turkey', 'Italy']           bat
# 4    Isle of Man   2024  ['Isle of Man', 'Luxembourg']           bat
#
#    toss.winner                       venue match_id outcome.result  \
# 0      Romania         Roma Cricket Ground  1436483            NaN
# 1       France  Simar Cricket Ground, Rome  1436484            NaN
# 2     Portugal         Roma Cricket Ground  1436485            NaN
# 3       Turkey  Simar Cricket Ground, Rome  1436486            NaN
# 4  Isle of Man         Roma Cricket Ground  1436487            NaN
#
#   outcome.eliminator
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
df[df["dates"] == "['2020-10-03', '2020-10-04']"]
# Out:
#              city                         dates      event.name gender  \
# 10468  Birmingham  ['2020-10-03', '2020-10-04']  Vitality Blast   male
#
#       match_type outcome.winner season                          teams  \
# 10468        T20         Surrey   2020  ['Gloucestershire', 'Surrey']
#
#       toss.decision toss.winner      venue match_id outcome.result  \
# 10468         field      Surrey  Edgbaston  1229397            NaN
#
#       outcome.eliminator
# 10468                NaN

# %% [markdown]
# ### **Creating Date Column**

# %%
# Clean up the dates column
df['dates'] = df['dates'].str.strip("[]").str.replace("'", "").str.strip()

# Extract the latest date in cases where there are multiple dates
def extract_latest_date(date_str):
    dates = date_str.split(', ')
    if len(dates) > 1:
        return dates[-1]
    else:
        return dates[0]

df['dates'] = df['dates'].apply(extract_latest_date)

# Convert the dates to datetime format
df['dates'] = pd.to_datetime(df['dates'], errors='coerce')

# Sort DataFrame by dates
df = df.sort_values(by="dates", ascending=False)

df[:10]
# Out:
#           city      dates                           event.name  gender  \
# 33     Utrecht 2024-06-19  Hong Kong Women tour of Netherlands  female
# 30    Episkopi 2024-06-19         Estonia Women tour of Cyprus  female
# 21    Episkopi 2024-06-19               Estonia tour of Cyprus    male
# 20    Episkopi 2024-06-19               Estonia tour of Cyprus    male
# 34     Utrecht 2024-06-19  Hong Kong Women tour of Netherlands  female
# 13  Hambantota 2024-06-18  West Indies Women tour of Sri Lanka  female
# 29    Episkopi 2024-06-18         Estonia Women tour of Cyprus  female
# 19    Episkopi 2024-06-18               Estonia tour of Cyprus    male
# 18    Episkopi 2024-06-18               Estonia tour of Cyprus    male
# 32     Utrecht 2024-06-18  Hong Kong Women tour of Netherlands  female
#
#    match_type outcome.winner season                         teams  \
# 33        T20    Netherlands   2024  ['Hong Kong', 'Netherlands']
# 30        T20         Cyprus   2024         ['Cyprus', 'Estonia']
# 21        T20        Estonia   2024         ['Estonia', 'Cyprus']
# 20        T20         Cyprus   2024         ['Estonia', 'Cyprus']
# 34        T20    Netherlands   2024  ['Netherlands', 'Hong Kong']
# 13        ODI      Sri Lanka   2024  ['West Indies', 'Sri Lanka']
# 29        T20         Cyprus   2024         ['Cyprus', 'Estonia']
# 19        T20        Estonia   2024         ['Estonia', 'Cyprus']
# 18        T20         Cyprus   2024         ['Cyprus', 'Estonia']
# 32        T20    Netherlands   2024  ['Hong Kong', 'Netherlands']
#
#    toss.decision  toss.winner  \
# 33         field  Netherlands
# 30         field      Estonia
# 21           bat      Estonia
# 20         field       Cyprus
# 34           bat  Netherlands
# 13           bat  West Indies
# 29         field      Estonia
# 19           bat      Estonia
# 18         field      Estonia
# 32         field  Netherlands
#
#                                                 venue match_id outcome.result  \
# 33               Sportpark Maarschalkerweerd, Utrecht  1438104            NaN
# 30                                Happy Valley Ground  1438101            NaN
# 21                                Happy Valley Ground  1438080            NaN
# 20                                Happy Valley Ground  1438079            NaN
# 34               Sportpark Maarschalkerweerd, Utrecht  1438105            NaN
# 13  Mahinda Rajapaksa International Cricket Stadiu...  1436887            NaN
# 29                                Happy Valley Ground  1438099            NaN
# 19                                Happy Valley Ground  1438078            NaN
# 18                                Happy Valley Ground  1438077            NaN
# 32               Sportpark Maarschalkerweerd, Utrecht  1438103            NaN
#
#    outcome.eliminator
# 33                NaN
# 30                NaN
# 21                NaN
# 20                NaN
# 34                NaN
# 13                NaN
# 29                NaN
# 19                NaN
# 18                NaN
# 32                NaN

# %%
df[df["match_id"].duplicated()]
# Out:
#                city      dates  \
# 17205        Kerava 2024-06-16
# 17202        Prague 2024-06-16
# 26           Prague 2024-06-16
# 8         Spinaceto 2024-06-16
# 9              Rome 2024-06-16
# ...             ...        ...
# 2439     Queenstown 2003-01-04
# 2438   Christchurch 2003-01-01
# 2359      Melbourne 2002-12-30
# 19529        Durban 2002-12-29
# 19605        Napier 2002-12-29
#
#                                               event.name  gender match_type  \
# 17205                                     Nordic T20 Cup    male        T20
# 17202                           Women Central Europe Cup  female        T20
# 26                              Women Central Europe Cup  female        T20
# 8      ICC Men's T20 World Cup Sub Regional Europe Qu...    male        T20
# 9      ICC Men's T20 World Cup Sub Regional Europe Qu...    male        T20
# ...                                                  ...     ...        ...
# 2439                           India tour of New Zealand    male        ODI
# 2438                           India tour of New Zealand    male        ODI
# 2359                           England tour of Australia    male       Test
# 19529                      Pakistan tour of South Africa    male       Test
# 19605                          India tour of New Zealand    male        ODI
#
#       outcome.winner   season                            teams toss.decision  \
# 17205         Norway     2024            ['Finland', 'Norway']           bat
# 17202      Gibraltar     2024  ['Gibraltar', 'Czech Republic']           bat
# 26         Gibraltar     2024         ['Croatia', 'Gibraltar']           bat
# 8             Israel     2024         ['Luxembourg', 'Israel']           bat
# 9            Austria     2024            ['France', 'Austria']         field
# ...              ...      ...                              ...           ...
# 2439     New Zealand  2002/03         ['India', 'New Zealand']         field
# 2438     New Zealand  2002/03         ['India', 'New Zealand']           bat
# 2359       Australia  2002/03         ['Australia', 'England']           bat
# 19529   South Africa  2002/03     ['South Africa', 'Pakistan']         field
# 19605    New Zealand  2002/03         ['New Zealand', 'India']         field
#
#        toss.winner                           venue match_id outcome.result  \
# 17205      Finland  Kerava National Cricket Ground  1438262            NaN
# 17202    Gibraltar         Scott Page Field, Vinor  1438095            NaN
# 26         Croatia         Scott Page Field, Vinor  1438094            NaN
# 8       Luxembourg             Roma Cricket Ground  1436491            NaN
# 9          Austria      Simar Cricket Ground, Rome  1436492            NaN
# ...            ...                             ...      ...            ...
# 2439   New Zealand         Davies Park, Queenstown    64816            NaN
# 2438         India      Jade Stadium, Christchurch    64815            NaN
# 2359     Australia        Melbourne Cricket Ground    64012            NaN
# 19529     Pakistan               Kingsmead, Durban    64022            NaN
# 19605        India             McLean Park, Napier    64814            NaN
#
#       outcome.eliminator
# 17205                NaN
# 17202                NaN
# 26                   NaN
# 8                    NaN
# 9                    NaN
# ...                  ...
# 2439                 NaN
# 2438                 NaN
# 2359                 NaN
# 19529                NaN
# 19605                NaN
#
# [5377 rows x 14 columns]

# %%
# Drop duplicates based on 'match_id' and reset the index in the original DataFrame
df.drop_duplicates(subset="match_id", inplace=True)
df.reset_index(drop=True, inplace=True)

# Print the resulting DataFrame to verify
df[:10]
# Out:
#          city      dates                           event.name  gender  \
# 0     Utrecht 2024-06-19  Hong Kong Women tour of Netherlands  female
# 1    Episkopi 2024-06-19         Estonia Women tour of Cyprus  female
# 2    Episkopi 2024-06-19               Estonia tour of Cyprus    male
# 3    Episkopi 2024-06-19               Estonia tour of Cyprus    male
# 4     Utrecht 2024-06-19  Hong Kong Women tour of Netherlands  female
# 5  Hambantota 2024-06-18  West Indies Women tour of Sri Lanka  female
# 6    Episkopi 2024-06-18         Estonia Women tour of Cyprus  female
# 7    Episkopi 2024-06-18               Estonia tour of Cyprus    male
# 8    Episkopi 2024-06-18               Estonia tour of Cyprus    male
# 9     Utrecht 2024-06-18  Hong Kong Women tour of Netherlands  female
#
#   match_type outcome.winner season                         teams  \
# 0        T20    Netherlands   2024  ['Hong Kong', 'Netherlands']
# 1        T20         Cyprus   2024         ['Cyprus', 'Estonia']
# 2        T20        Estonia   2024         ['Estonia', 'Cyprus']
# 3        T20         Cyprus   2024         ['Estonia', 'Cyprus']
# 4        T20    Netherlands   2024  ['Netherlands', 'Hong Kong']
# 5        ODI      Sri Lanka   2024  ['West Indies', 'Sri Lanka']
# 6        T20         Cyprus   2024         ['Cyprus', 'Estonia']
# 7        T20        Estonia   2024         ['Estonia', 'Cyprus']
# 8        T20         Cyprus   2024         ['Cyprus', 'Estonia']
# 9        T20    Netherlands   2024  ['Hong Kong', 'Netherlands']
#
#   toss.decision  toss.winner  \
# 0         field  Netherlands
# 1         field      Estonia
# 2           bat      Estonia
# 3         field       Cyprus
# 4           bat  Netherlands
# 5           bat  West Indies
# 6         field      Estonia
# 7           bat      Estonia
# 8         field      Estonia
# 9         field  Netherlands
#
#                                                venue match_id outcome.result  \
# 0               Sportpark Maarschalkerweerd, Utrecht  1438104            NaN
# 1                                Happy Valley Ground  1438101            NaN
# 2                                Happy Valley Ground  1438080            NaN
# 3                                Happy Valley Ground  1438079            NaN
# 4               Sportpark Maarschalkerweerd, Utrecht  1438105            NaN
# 5  Mahinda Rajapaksa International Cricket Stadiu...  1436887            NaN
# 6                                Happy Valley Ground  1438099            NaN
# 7                                Happy Valley Ground  1438078            NaN
# 8                                Happy Valley Ground  1438077            NaN
# 9               Sportpark Maarschalkerweerd, Utrecht  1438103            NaN
#
#   outcome.eliminator
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN

# %%
df["dates"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### **Seasons**

# %%
df["season"].unique()
# Out:
# array(['2024', '2023/24', '2023', '2022/23', '2022', '2021/22', '2021',
#        '2020/21', '2020', '2019/20', '2019', '2018/19', '2018', '2017/18',
#        '2017', '2016/17', '2016', '2015/16', '2015', '2014/15', '2014',
#        '2013/14', '2013', '2012/13', '2012', '2011/12', '2011', '2010/11',
#        '2010', '2009/10', '2009', '2008/09', '2008', '2007/08', '2007',
#        '2006/07', '2006', '2005/06', '2005', '2004/05', '2004', '2003/04',
#        '2003', '2002/03'], dtype=object)

# %%
df["season"] = df["dates"].dt.year

# %%
df["season"].unique()
# Out:
# array([2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014,
#        2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003,
#        2002])

# %% [markdown]
# ### **Create team columns**

# %%
# Splitting the teams into team1 and team2 columns
teams = df['teams'].str.strip("[]").str.replace("'", "").str.split(', ', expand=True)
df['team1'] = teams[0]
df['team2'] = teams[1]

# Dropping the original 'teams' column
df.drop('teams', axis=1, inplace=True)

df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#        city      dates                           event.name  gender  \
# 0   Utrecht 2024-06-19  Hong Kong Women tour of Netherlands  female
# 1  Episkopi 2024-06-19         Estonia Women tour of Cyprus  female
# 2  Episkopi 2024-06-19               Estonia tour of Cyprus    male
# 3  Episkopi 2024-06-19               Estonia tour of Cyprus    male
# 4   Utrecht 2024-06-19  Hong Kong Women tour of Netherlands  female
#
#   match_type outcome.winner  season toss.decision  toss.winner  \
# 0        T20    Netherlands    2024         field  Netherlands
# 1        T20         Cyprus    2024         field      Estonia
# 2        T20        Estonia    2024           bat      Estonia
# 3        T20         Cyprus    2024         field       Cyprus
# 4        T20    Netherlands    2024           bat  Netherlands
#
#                                   venue match_id outcome.result  \
# 0  Sportpark Maarschalkerweerd, Utrecht  1438104            NaN
# 1                   Happy Valley Ground  1438101            NaN
# 2                   Happy Valley Ground  1438080            NaN
# 3                   Happy Valley Ground  1438079            NaN
# 4  Sportpark Maarschalkerweerd, Utrecht  1438105            NaN
#
#   outcome.eliminator        team1        team2
# 0                NaN    Hong Kong  Netherlands
# 1                NaN       Cyprus      Estonia
# 2                NaN      Estonia       Cyprus
# 3                NaN      Estonia       Cyprus
# 4                NaN  Netherlands    Hong Kong

# %%
df.columns
# Out:
# Index(['city', 'dates', 'event.name', 'gender', 'match_type', 'outcome.winner',
#        'season', 'toss.decision', 'toss.winner', 'venue', 'match_id',
#        'outcome.result', 'outcome.eliminator', 'team1', 'team2'],
#       dtype='object')

# %% [markdown]
# ### **Check Unique Values & Clean the Data**

# %%
print("No of Teams:",df["team1"].nunique())
df["team1"].unique()[:10]
# Out:
# No of Teams: 345
# array(['Hong Kong', 'Cyprus', 'Estonia', 'Netherlands', 'West Indies',
#        'Gibraltar', 'Derbyshire', 'Finland', 'Croatia', 'India'],
#       dtype=object)

# %%
print("No of Teams:",df["team1"].nunique())
df["team2"].unique()[:10]
# Out:
# No of Teams: 345
# array(['Netherlands', 'Estonia', 'Cyprus', 'Hong Kong', 'Sri Lanka',
#        'Czech Republic', 'Birmingham Bears', 'Norway', 'Gibraltar',
#        'South Africa'], dtype=object)

# %%
print("No of Outcomes:",df["team1"].nunique())
df["outcome.winner"].unique()[:10]
# Out:
# No of Outcomes: 345
# array(['Netherlands', 'Cyprus', 'Estonia', 'Sri Lanka', 'Gibraltar',
#        'Birmingham Bears', 'Norway', 'India', 'Jersey', 'Israel'],
#       dtype=object)

# %%
print("Toss Decisions:",df["toss.decision"].nunique())
df["toss.decision"].unique()
# Out:
# Toss Decisions: 2
# array(['field', 'bat'], dtype=object)

# %%
print("Venues: ", df["venue"].nunique())
sorted(df["venue"].unique())[:10]
# Out:
# Venues:  796
# [' Emerald Heights International School Ground',
#  '7he Sevens Stadium, Dubai',
#  'ACA Stadium, Barsapara',
#  'ACA Stadium,Mangalagiri',
#  'AMI Stadium',
#  'Abhimanyu Cricket Academy, Dehradun',
#  'Abu Dhabi Oval 1',
#  'Abu Dhabi Oval 2',
#  'Achimota Senior Secondary School A Field, Accra',
#  'Achimota Senior Secondary School B Field, Accra']

# %%
df["match_type"].unique()
# Out:
# array(['T20', 'ODI', 'ODM', 'MDM', 'Test', 'IT20'], dtype=object)

# %%
# Display the updated DataFrame
print("Venues: ", df["venue"].nunique())
df[:5]
# Out:
# Venues:  796
#        city      dates                           event.name  gender  \
# 0   Utrecht 2024-06-19  Hong Kong Women tour of Netherlands  female
# 1  Episkopi 2024-06-19         Estonia Women tour of Cyprus  female
# 2  Episkopi 2024-06-19               Estonia tour of Cyprus    male
# 3  Episkopi 2024-06-19               Estonia tour of Cyprus    male
# 4   Utrecht 2024-06-19  Hong Kong Women tour of Netherlands  female
#
#   match_type outcome.winner  season toss.decision  toss.winner  \
# 0        T20    Netherlands    2024         field  Netherlands
# 1        T20         Cyprus    2024         field      Estonia
# 2        T20        Estonia    2024           bat      Estonia
# 3        T20         Cyprus    2024         field       Cyprus
# 4        T20    Netherlands    2024           bat  Netherlands
#
#                                   venue match_id outcome.result  \
# 0  Sportpark Maarschalkerweerd, Utrecht  1438104            NaN
# 1                   Happy Valley Ground  1438101            NaN
# 2                   Happy Valley Ground  1438080            NaN
# 3                   Happy Valley Ground  1438079            NaN
# 4  Sportpark Maarschalkerweerd, Utrecht  1438105            NaN
#
#   outcome.eliminator        team1        team2
# 0                NaN    Hong Kong  Netherlands
# 1                NaN       Cyprus      Estonia
# 2                NaN      Estonia       Cyprus
# 3                NaN      Estonia       Cyprus
# 4                NaN  Netherlands    Hong Kong

# %%
df.columns
# Out:
# Index(['city', 'dates', 'event.name', 'gender', 'match_type', 'outcome.winner',
#        'season', 'toss.decision', 'toss.winner', 'venue', 'match_id',
#        'outcome.result', 'outcome.eliminator', 'team1', 'team2'],
#       dtype='object')

# %%
df = df[['match_id','season', 'dates','event.name', 'gender','match_type', 'team1', 'team2', 'toss.winner','toss.decision',  'outcome.winner', 'outcome.result', 'outcome.eliminator', 'venue', "city"]]

# %%
df.columns = ['match_id', 'season', 'match_date', 'event_name', 'gender', 'match_type', 'team1', 'team2','toss_winner', 'toss_decision', 'winner', 'outcome_result', 'outcome_eliminator','ground', 'city' ]

# %%
df.isnull().sum()
# Out:
# match_id                  0
# season                    0
# match_date                0
# event_name               92
# gender                    0
# match_type                0
# team1                     0
# team2                     0
# toss_winner               0
# toss_decision             0
# winner                 1301
# outcome_result        15881
# outcome_eliminator    17098
# ground                    0
# city                   1699
# dtype: int64

# %% [markdown]
# ### **Winner**

# %%
df[df['winner'].isnull()]
# Out:
#       match_id  season match_date                       event_name  gender  \
# 42     1410420    2024 2024-06-15                   Vitality Blast    male
# 57     1410414    2024 2024-06-14                   Vitality Blast    male
# 59     1410417    2024 2024-06-14                   Vitality Blast    male
# 128    1415711    2024 2024-06-06          ICC Men's T20 World Cup    male
# 141    1415706    2024 2024-06-04          ICC Men's T20 World Cup    male
# ...        ...     ...        ...                              ...     ...
# 17106    66356    2003 2003-04-21             TVS Cup (Bangladesh)    male
# 17126    65273    2003 2003-03-04                    ICC World Cup    male
# 17128    65272    2003 2003-03-03                    ICC World Cup    male
# 17139    67517    2003 2003-02-25  England Women tour of Australia  female
# 17150    65249    2003 2003-02-18                    ICC World Cup    male
#
#       match_type            team1                     team2  \
# 42           T20           Durham           Nottinghamshire
# 57           T20        Middlesex                 Hampshire
# 59           T20  Gloucestershire                    Surrey
# 128          T20         Pakistan  United States of America
# 141          T20         Scotland                   England
# ...          ...              ...                       ...
# 17106        ODI            India              South Africa
# 17126        ODI         Pakistan                  Zimbabwe
# 17128        ODI        Sri Lanka              South Africa
# 17139       Test        Australia                   England
# 17150        ODI      West Indies                Bangladesh
#
#                     toss_winner toss_decision winner outcome_result  \
# 42              Nottinghamshire         field    NaN      no result
# 57                    Hampshire         field    NaN      no result
# 59                       Surrey         field    NaN            tie
# 128    United States of America         field    NaN            tie
# 141                    Scotland           bat    NaN      no result
# ...                         ...           ...    ...            ...
# 17106                     India           bat    NaN      no result
# 17126                  Pakistan           bat    NaN      no result
# 17128                 Sri Lanka           bat    NaN            tie
# 17139                   England         field    NaN           draw
# 17150                Bangladesh         field    NaN      no result
#
#              outcome_eliminator                                 ground  \
# 42                          NaN               Trent Bridge, Nottingham
# 57                          NaN             The Rose Bowl, Southampton
# 59                          NaN                Kennington Oval, London
# 128    United States of America          Grand Prairie Stadium, Dallas
# 141                         NaN  Kensington Oval, Bridgetown, Barbados
# ...                         ...                                    ...
# 17106                       NaN    Bangabandhu National Stadium, Dhaka
# 17126                       NaN           Queens Sports Club, Bulawayo
# 17128                       NaN                      Kingsmead, Durban
# 17139                       NaN                 Bankstown Oval, Sydney
# 17150                       NaN               Willowmoore Park, Benoni
#
#               city
# 42      Nottingham
# 57     Southampton
# 59          London
# 128         Dallas
# 141     Bridgetown
# ...            ...
# 17106        Dhaka
# 17126     Bulawayo
# 17128       Durban
# 17139       Sydney
# 17150       Benoni
#
# [1301 rows x 15 columns]

# %%
# Check if "winner" column is null, and if so, fill it with values from "outcome_eliminator"
df["winner"] = df["winner"].fillna(df["outcome_eliminator"])

# If "outcome_eliminator" is also null, fill "winner" with values from "outcome_result"
df["winner"] = df["winner"].fillna(df["outcome_result"])

df.drop(columns=["outcome_result", "outcome_eliminator"], inplace=True)

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#       match_id  season match_date                           event_name  \
# 0      1438104    2024 2024-06-19  Hong Kong Women tour of Netherlands
# 1      1438101    2024 2024-06-19         Estonia Women tour of Cyprus
# 2      1438080    2024 2024-06-19               Estonia tour of Cyprus
# 3      1438079    2024 2024-06-19               Estonia tour of Cyprus
# 4      1438105    2024 2024-06-19  Hong Kong Women tour of Netherlands
# ...        ...     ...        ...                                  ...
# 17177    64816    2003 2003-01-04            India tour of New Zealand
# 17178    64815    2003 2003-01-01            India tour of New Zealand
# 17179    64012    2002 2002-12-30            England tour of Australia
# 17180    64022    2002 2002-12-29        Pakistan tour of South Africa
# 17181    64814    2002 2002-12-29            India tour of New Zealand
#
#        gender match_type         team1        team2  toss_winner  \
# 0      female        T20     Hong Kong  Netherlands  Netherlands
# 1      female        T20        Cyprus      Estonia      Estonia
# 2        male        T20       Estonia       Cyprus      Estonia
# 3        male        T20       Estonia       Cyprus       Cyprus
# 4      female        T20   Netherlands    Hong Kong  Netherlands
# ...       ...        ...           ...          ...          ...
# 17177    male        ODI         India  New Zealand  New Zealand
# 17178    male        ODI         India  New Zealand        India
# 17179    male       Test     Australia      England    Australia
# 17180    male       Test  South Africa     Pakistan     Pakistan
# 17181    male        ODI   New Zealand        India        India
#
#       toss_decision        winner                                ground  \
# 0             field   Netherlands  Sportpark Maarschalkerweerd, Utrecht
# 1             field        Cyprus                   Happy Valley Ground
# 2               bat       Estonia                   Happy Valley Ground
# 3             field        Cyprus                   Happy Valley Ground
# 4               bat   Netherlands  Sportpark Maarschalkerweerd, Utrecht
# ...             ...           ...                                   ...
# 17177         field   New Zealand               Davies Park, Queenstown
# 17178           bat   New Zealand            Jade Stadium, Christchurch
# 17179           bat     Australia              Melbourne Cricket Ground
# 17180         field  South Africa                     Kingsmead, Durban
# 17181         field   New Zealand                   McLean Park, Napier
#
#                city
# 0           Utrecht
# 1          Episkopi
# 2          Episkopi
# 3          Episkopi
# 4           Utrecht
# ...             ...
# 17177    Queenstown
# 17178  Christchurch
# 17179     Melbourne
# 17180        Durban
# 17181        Napier
#
# [17182 rows x 13 columns]

# %% [markdown]
# ### **Cleaning Ground Name**

# %%
df[df["ground"].isnull()]
# Out:
# Empty DataFrame
# Columns: [match_id, season, match_date, event_name, gender, match_type, team1, team2, toss_winner, toss_decision, winner, ground, city]
# Index: []

# %%
df[df["city"].isnull()]
# Out:
#       match_id  season match_date                  event_name gender  \
# 541    1391925    2024 2024-03-27              Plunket Shield   male
# 542    1391926    2024 2024-03-27              Plunket Shield   male
# 545    1391924    2024 2024-03-26              Plunket Shield   male
# 568    1391921    2024 2024-03-19              Plunket Shield   male
# 569    1391923    2024 2024-03-19              Plunket Shield   male
# ...        ...     ...        ...                         ...    ...
# 16885   217481    2005 2005-08-29  Videocon Triangular Series   male
# 16892   214852    2005 2005-08-02              Indian Oil Cup   male
# 16893   214742    2005 2005-07-31              Indian Oil Cup   male
# 16930    65666    2005 2005-02-04                   VB Series   male
# 16937    65662    2005 2005-01-26                   VB Series   male
#
#       match_type               team1                 team2  \
# 541          MDM  Northern Districts  Wellington Firebirds
# 542          MDM       Central Stags           Otago Volts
# 545          MDM       Auckland Aces            Canterbury
# 568          MDM       Central Stags         Auckland Aces
# 569          MDM          Canterbury    Northern Districts
# ...          ...                 ...                   ...
# 16885        ODI               India              Zimbabwe
# 16892        ODI           Sri Lanka           West Indies
# 16893        ODI         West Indies                 India
# 16930        ODI           Australia              Pakistan
# 16937        ODI           Australia           West Indies
#
#                 toss_winner toss_decision         winner  \
# 541    Wellington Firebirds           bat           draw
# 542           Central Stags         field  Central Stags
# 545              Canterbury         field     Canterbury
# 568           Central Stags         field  Auckland Aces
# 569              Canterbury         field     Canterbury
# ...                     ...           ...            ...
# 16885              Zimbabwe         field          India
# 16892             Sri Lanka           bat      Sri Lanka
# 16893           West Indies           bat          India
# 16930             Australia           bat      Australia
# 16937             Australia           bat      Australia
#
#                                        ground city
# 541                               Seddon Park  NaN
# 542                               McLean Park  NaN
# 545              Kennards Hire Community Oval  NaN
# 568                               McLean Park  NaN
# 569                            Mainpower Oval  NaN
# ...                                       ...  ...
# 16885                      Harare Sports Club  NaN
# 16892  Rangiri Dambulla International Stadium  NaN
# 16893  Rangiri Dambulla International Stadium  NaN
# 16930                Melbourne Cricket Ground  NaN
# 16937                           Adelaide Oval  NaN
#
# [1699 rows x 13 columns]

# %%
df['city'] = df['city'].fillna('')

# Concatenate 'ground' and 'city' columns
df.loc[:, 'ground'] = df['ground'] + "," + df['city']

# Remove any leading or trailing commas and spaces
df['ground'] = df['ground'].str.strip(', ')

# %%
# Drop the 'city' column
df = df.drop(columns="city")

# %%
def clean_ground_name(ground):
    if isinstance(ground, str):
        parts = ground.rsplit(',', 1)  # Split by the last comma
        if len(parts) == 2 and parts[0].endswith(parts[1]):
            return parts[0]
    return ground

def add_space_after_last_comma(value):
    if isinstance(value, str):
        last_comma_index = value.rfind(',')
        if last_comma_index != -1:
            value = value[:last_comma_index + 1] + ' ' + value[last_comma_index + 1:].strip()
    return value


# Apply the function to the 'ground' column
df['ground'] = df['ground'].apply(clean_ground_name)
df['ground'] = df['ground'].apply(add_space_after_last_comma)

# Display the modified DataFrame
df[:10]
# Out:
#   match_id  season match_date                           event_name  gender  \
# 0  1438104    2024 2024-06-19  Hong Kong Women tour of Netherlands  female
# 1  1438101    2024 2024-06-19         Estonia Women tour of Cyprus  female
# 2  1438080    2024 2024-06-19               Estonia tour of Cyprus    male
# 3  1438079    2024 2024-06-19               Estonia tour of Cyprus    male
# 4  1438105    2024 2024-06-19  Hong Kong Women tour of Netherlands  female
# 5  1436887    2024 2024-06-18  West Indies Women tour of Sri Lanka  female
# 6  1438099    2024 2024-06-18         Estonia Women tour of Cyprus  female
# 7  1438078    2024 2024-06-18               Estonia tour of Cyprus    male
# 8  1438077    2024 2024-06-18               Estonia tour of Cyprus    male
# 9  1438103    2024 2024-06-18  Hong Kong Women tour of Netherlands  female
#
#   match_type        team1        team2  toss_winner toss_decision  \
# 0        T20    Hong Kong  Netherlands  Netherlands         field
# 1        T20       Cyprus      Estonia      Estonia         field
# 2        T20      Estonia       Cyprus      Estonia           bat
# 3        T20      Estonia       Cyprus       Cyprus         field
# 4        T20  Netherlands    Hong Kong  Netherlands           bat
# 5        ODI  West Indies    Sri Lanka  West Indies           bat
# 6        T20       Cyprus      Estonia      Estonia         field
# 7        T20      Estonia       Cyprus      Estonia           bat
# 8        T20       Cyprus      Estonia      Estonia         field
# 9        T20    Hong Kong  Netherlands  Netherlands         field
#
#         winner                                             ground
# 0  Netherlands               Sportpark Maarschalkerweerd, Utrecht
# 1       Cyprus                      Happy Valley Ground, Episkopi
# 2      Estonia                      Happy Valley Ground, Episkopi
# 3       Cyprus                      Happy Valley Ground, Episkopi
# 4  Netherlands               Sportpark Maarschalkerweerd, Utrecht
# 5    Sri Lanka  Mahinda Rajapaksa International Cricket Stadiu...
# 6       Cyprus                      Happy Valley Ground, Episkopi
# 7      Estonia                      Happy Valley Ground, Episkopi
# 8       Cyprus                      Happy Valley Ground, Episkopi
# 9  Netherlands               Sportpark Maarschalkerweerd, Utrecht

# %%
# Sort the values in the 'ground' column and drop duplicates
ground_sorted = df['ground'].sort_values().drop_duplicates()

# Define the path to save the CSV file
output_path = r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\grounds.csv"

# Save the Series to a CSV file
ground_sorted.to_csv(output_path, index=False)

# %% [markdown]
# ### **Replacing the Neccesary Features**

# %% [markdown]
# #### **Grounds**

# %%
replacement1 = {"Adelaide Oval" : "Adelaide Oval, Adelaide", 
                "Andhra Cricket Association-Visakhapatnam District Cricket Association Stadium, Visakhapatnam" : "Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam", # YSR Stadium
                "Dr. Y.S. Rajasekhara Reddy ACA VDCA Cricket Stadium" : "Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam",
                "Al Amerat Cricket Ground Oman Cricket (Ministry Turf 1)" : "Al Amerat Cricket Ground Oman Cricket (Ministry Turf 1), Al Amarat",
                "Al Amerat Cricket Ground Oman Cricket (Ministry Turf 2)" : "Al Amerat Cricket Ground Oman Cricket (Ministry Turf 2), Al Amarat",
                "Antigua Recreation Ground, St John's" : "Antigua Recreation Ground, St John's, Antigua, St John's",
                "Antigua Recreation Ground, St John's, Antigua" : "Antigua Recreation Ground, St John's, Antigua, St John's",
                "Arnos Vale Ground, Kingstown" : "Arnos Vale Ground, Kingstown, St Vincent, Kingstown",
                "Arnos Vale Ground, Kingstown, St Vincent" : "Arnos Vale Ground, Kingstown, St Vincent, Kingstown",
                "Arun Jaitley Stadium" : "Arun Jaitley Stadium, Delhi", "Arundel Castle Cricket Club Ground" : "Arundel Castle Cricket Club Ground, Arundel",
                "Barabati Stadium" : "Barabati Stadium, Cuttack","Bay Oval" : "Bay Oval, Mount Maunganui",
                "Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium" : "Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow",
                "Bharat Ratna Shri Atal Bihari Vajpai Ekana Cricket Stadium, Lucknow": "Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow",
                "Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium B" : "Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow" ,
                "Bready Cricket Club, Magheramason, Bready": "Bready Cricket Club, Magheramason, Londonderry", 
                "Brian Lara Stadium, Tarouba, Trinidad" : "Brian Lara Stadium, Tarouba, Trinidad, Tarouba",
                "Brisbane Cricket Ground, Brisbane" : "Brisbane Cricket Ground, Woolloongabba, Brisbane",
                "Bulawayo Athletic Club" : "Bulawayo Athletic Club, Bulawayo","Boland Park, Paarl" : "Boland Bank Park, Paarl","Bready, Derry" : "Bready Cricket Club, Magheramason, Londonderry",
                "Carrara Oval" : "Carrara Oval, Carrara","Colin Maiden Park" : "Colin Maiden Park, Auckland","Coolidge Cricket Ground, Antigua" : "Coolidge Cricket Ground, Antigua, Coolidge",
                "County Ground, Hove" : "County Ground, Hove, Brighton","Casey Fields No 4, Melbourne" : "Casey Fields No. 4, Melbourne",
                "Daren Sammy National Cricket Stadium, Gros Islet, St Lucia, Gros Islet" : "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Darren Sammy National Cricket Stadium, St Lucia, Gros Islet" : "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Daren Sammy National Cricket Stadium, Gros Islet" : "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Daren Sammy National Cricket Stadium, Gros Islet, St Lucia, Gros Islet" : "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Daren Sammy National Cricket Stadium, Gros Islet, St Lucia" : "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Daren Sammy National Cricket Stadium, St Lucia, Gros Islet" : "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia": "Darren Sammy National Cricket Stadium, Gros Islet, St Lucia",
                "Dr DY Patil Sports Academy, Mumbai" : "Dr DY Patil Sports Academy, Mumbai, Navi Mumbai", "Dubai International Cricket Stadium" : "Dubai International Cricket Stadium, Dubai", 
                "Dubai Sports City Cricket Stadium" : "Dubai International Cricket Stadium, Dubai",
                "Eden Gardens" : "Eden Gardens, Kolkata", "Eden Park" : "Eden Park, Auckland", "Entebbe Cricket Oval" : "Entebbe Cricket Oval, Entebbe", 
                "Edgbaston, Birmingham" : "Edgbaston Foundation Community Sports Ground, Birmingham", "Fitzherbert Park" : "Fitzherbert Park, Palmerston North", 
                "Gahanga International Cricket Stadium. Rwanda" : "Gahanga International Cricket Stadium, Rwanda, Kigali City",
                "Gahanga International Cricket Stadium. Rwanda, Kigali City" : "Gahanga International Cricket Stadium, Rwanda, Kigali City",
                "Galle International Stadium" : "Galle International Stadium, Galle", "Grainville, St Saviour" : "Grainville, St Saviour, Jersey, St Saviour",
                "Grange Cricket Club Ground, Raeburn Place, Edinburgh" : "Grange Cricket Club, Raeburn Place, Edinburgh",
                "Greenfield Stadium" : "Greenfield International Stadium, Thiruvananthapuram", "Hagley Oval" : "Hagley Oval, Christchurch","Harare Sports Club" : "Harare Sports Club, Harare" }

replacement2 = {"Himachal Pradesh Cricket Association Stadium, Dharamsala" : "Himachal Pradesh Cricket Association Stadium, Dharmasala",
                "Hong Kong Cricket Club" : "Hong Kong Cricket Club, Wong Nai Chung Gap", "Holkar Stadium" : "Holkar Cricket Stadium, Indore",
                "ICC Academy, Dubai" : "ICC Global Cricket Academy, Dubai","JSCA International Stadium Complex" : "JSCA International Stadium Complex, Ranchi",
                "Johor Cricket Academy Oval" : "Johor Cricket Academy Oval, Johor","Kensington Oval, Bridgetown": "Kensington Oval, Barbados, Bridgetown", 
                "Kensington Oval, Bridgetown, Barbados" : "Kensington Oval, Barbados, Bridgetown","Kensington Oval, Bridgetown, Barbados, Bridgetown" : "Kensington Oval, Barbados, Bridgetown",
                "Kinrara Oval, Kuala Lumpur" : "Kinrara Academy Oval, Kuala Lumpur", "Kyambogo Cricket Oval, Kampala" : "Kyambogo Cricket Ground, Kampala",
                "Lalbhai Contractor Stadium" : "Lalabhai Contractor Stadium, Surat", "M Chinnaswamy Stadium, Bangalore, Bengaluru" : "M Chinnaswamy Stadium, Bengaluru", 
                "M Chinnaswamy Stadium, Bangalore" : "M Chinnaswamy Stadium, Bengaluru","M.Chinnaswamy Stadium, Bengaluru" : "M Chinnaswamy Stadium, Bengaluru", 
                "MA Aziz Stadium, Chattogram" : "MA Aziz Stadium, Chittagong, Chattogram","MA Chidambaram Stadium, Chennai" : "MA Chidambaram Stadium, Chepauk, Chennai",
                "Mainpower Oval" : "Mainpower Oval, Rangiora","McLean Park" : "McLean Park, Napier", "Melbourne Cricket Ground" : "Melbourne Cricket Ground, Melbourne",
                "Mission Road Ground, Mong Kok, Hong Kong" : "Mission Road Ground, Mong Kok, Hong Kong, Mong Kok", "Moara Vlasiei Cricket Ground" : "Moara Vlasiei Cricket Ground, Ilfov County", 
                "Molyneux Park" : "Molyneux Park, Alexandra", "Multan Cricket Stadium" : "Multan Cricket Stadium, Multan",  
                "National Cricket Stadium, Grenada, St George's" : "National Cricket Stadium, St George's, Grenada", "National Cricket Stadium, St George's" : "National Cricket Stadium, St George's, Grenada",
                "National Cricket Stadium, St George's, Grenada, St George's" : "National Cricket Stadium, St George's, Grenada", "Nelson Park" : "Nelson Park, Napier",
                "Narendra Modi Stadium Ground 'A', Motera" : "Narendra Modi Stadium, Ahmedabad","Nehru Stadium, Poona, Pune": "Nehru Stadium, Pune",
                "Nehru Stadium" : "Nehru Stadium, Guwahati", "Old Hararians, Harare" : "Old Hararians Sports Club, Harare",
                "Pallekele International Cricket Stadium, Kandy" : "Pallekele International Cricket Stadium", "Pallekele International Cricket Stadium, Pallekele" : "Pallekele International Cricket Stadium",
                "Perth Stadium" : "Perth Stadium, Perth", "Providence Stadium, Guyana" : "Providence Stadium, Guyana, Providence", 
                "Punjab Cricket Association IS Bindra Stadium, Chandigarh" : "Punjab Cricket Association Stadium, Mohali, Chandigarh", 
                "Punjab Cricket Association IS Bindra Stadium, Mohali" : "Punjab Cricket Association Stadium, Mohali, Chandigarh",
                "Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh" : "Punjab Cricket Association Stadium, Mohali, Chandigarh",
                "Queen's Park Oval, Port of Spain": "Queen's Park Oval, Port of Spain, Trinidad","Queen's Park Oval, Port of Spain, Trinidad, Port of Spain": "Queen's Park Oval, Port of Spain, Trinidad",
                "Queen's Park" : "Queen's Park, Invercargill","Queen's Park Oval, Trinidad, Port of Spain": "Queen's Park Oval, Port of Spain, Trinidad", "Queenstown Events Centre" : "Queenstown Events Centre, Queenstown", 
                "R.Premadasa Stadium, Colombo" : "R.Premadasa Stadium, Khettarama, Colombo", "R Premadasa Stadium, Colombo" : "R.Premadasa Stadium, Khettarama, Colombo",
                "Rajiv Gandhi International Cricket Stadium, Dehradun, Dehra Dun" : "Rajiv Gandhi International Cricket Stadium, Dehradun"
                }

replacement3 = {"Rajiv Gandhi International Stadium, Hyderabad" : "Rajiv Gandhi International Stadium, Uppal, Hyderabad", "Rangiri Dambulla International Stadium" : "Rangiri Dambulla International Stadium, Dambulla", 
                "Rawalpindi Cricket Stadium" : "Rawalpindi Cricket Stadium, Rawalpindi","Reliance Cricket Stadium" : "Reliance Stadium, Vadodara", "Royal Chiangmai Golf Club" : "Royal Chiangmai Golf Club, Chiang Mai",
                "Sabina Park, Kingston, Jamaica, Kingston": "Sabina Park, Kingston, Jamaica" ,"Sabina Park, Jamaica, Kingston" : "Sabina Park, Kingston, Jamaica",
                "Sano International Cricket Ground" : "Sano International Cricket Ground, Sano", "Sardar Patel Stadium, Motera, Ahmedabad" : "Sardar Patel (Gujarat) Stadium, Motera, Ahmedabad",
                "Sardar Patel Stadium, Ahmedabad" : "Sardar Patel (Gujarat) Stadium, Motera, Ahmedabad", "Saurashtra Cricket Association Stadium" : "Saurashtra Cricket Association Stadium, Rajkot", 
                "Saxton Oval" : "Saxton Oval, Nelson", "Seddon Park" : "Seddon Park, Hamilton", "Shaheed Veer Narayan Singh International Stadium" : "Shaheed Veer Narayan Singh International Stadium, Raipur",
                "Sharjah Cricket Association Stadium" : "Sharjah Cricket Association Stadium, Sharjah", "Sharjah Cricket Stadium" : "Sharjah Cricket Association Stadium, Sharjah",
                "Sharjah Cricket Stadium, Sharjah" : "Sharjah Cricket Association Stadium, Sharjah",
                "Shere Bangla National Stadium, Dhaka" : "Shere Bangla National Stadium, Mirpur, Dhaka", "Shere Bangla National Stadium, Mirpur" : "Shere Bangla National Stadium, Mirpur, Dhaka", 
                "Simonds Stadium, South Geelong, Victoria" : "Simonds Stadium, South Geelong, Victoria, Geelong", "Singapore Cricket Club, Singapore" : "Singapore Cricket Club, Padang", 
                "Sher-e-Bangla National Cricket Stadium, Mirpur" : "Shere Bangla National Stadium, Mirpur, Dhaka", "Sinhalese Sports Club, Colombo" : "Sinhalese Sports Club Ground, Colombo", 
                "Sir Vivian Richards Stadium, Antigua, North Sound" : "Sir Vivian Richards Stadium, North Sound, Antigua", "Sir Vivian Richards Stadium, North Sound" : "Sir Vivian Richards Stadium, North Sound, Antigua",
                "Sir Vivian Richards Stadium, North Sound, Antigua, North Sound": "Sir Vivian Richards Stadium, North Sound, Antigua","Sportpark Westvliet, The Hague" : "Sportpark Westvliet, Voorburg, The Hague", 
                "Sportpark Westvliet, Voorburg" : "Sportpark Westvliet, Voorburg, The Hague", "Tafawa Balewa Square (TBS) Cricket Oval" : "Tafawa Balewa Square Cricket Oval, Lagos",
                "St George's Park, Gqeberha" : "St George's Park, Port Elizabeth, Gqeberha", "St George's Park, Port Elizabeth" : "St George's Park, Port Elizabeth, Gqeberha",
                "Sydney Cricket Ground" : "Sydney Cricket Ground, Sydney", "Sydney Showground Stadium" : "Sydney Showground Stadium, Sydney", 
                "Sylhet International Cricket Stadium" : "Sylhet International Cricket Stadium, Academy Ground, Sylhet", 
                "Sylhet International Cricket Stadium, Sylhet" : "Sylhet International Cricket Stadium, Academy Ground, Sylhet", "Sylhet Stadium" : "Sylhet International Cricket Stadium, Academy Ground, Sylhet",
                "Takashinga Sports Club, Harare" : "Takashinga Sports Club, Highfield, Harare", "VRA Ground, Amstelveen" : "VRA Cricket Ground, Amstelveen", 
                "Vidarbha Cricket Association Stadium, Jamtha" : "Vidarbha Cricket Association Stadium, Jamtha, Nagpur", "Wanderers, Windhoek" : "Wanderers Cricket Ground, Windhoek",
                "Wankhede Stadium" : "Wankhede Stadium, Mumbai", "Warner Park, Basseterre": "Warner Park, Basseterre, St Kitts", "Warner Park, Basseterre, St Kitts, Basseterre": "Warner Park, Basseterre, St Kitts",
                "Warner Park, St Kitts, Basseterre": "Warner Park, Basseterre, St Kitts", "Vidarbha C.A. Ground, Nagpur" : "Vidarbha Cricket Association Stadium, Jamtha, Nagpur",
                "Vidarbha Cricket Association Ground, Nagpur" : "Vidarbha Cricket Association Stadium, Jamtha, Nagpur", "Zohur Ahmed Chowdhury Stadium, Chittagong" : "Zahur Ahmed Chowdhury Stadium, Chittagong, Chattogram",
                "Zahur Ahmed Chowdhury Stadium, Chattogram" : "Zahur Ahmed Chowdhury Stadium, Chittagong, Chattogram", "Zahur Ahmed Chowdhury Stadium, Chittagong" : "Zahur Ahmed Chowdhury Stadium, Chittagong, Chattogram",
                "Westpac Stadium" : "Westpac Stadium, Wellington", "Windsor Park, Roseau, Dominica" : "Windsor Park, Roseau, Dominica, Roseau"
                 }

replacements = {**replacement1, **replacement2, **replacement3}

df['ground'] = df['ground'].replace(replacements)

print("Grounds: ",df['ground'].nunique())
# Out:
# Grounds:  536

# %%
# Sort the values in the 'ground' column and drop duplicates
ground_sorted = df['ground'].sort_values().drop_duplicates()

# Define the path to save the CSV file
output_path = r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\cleaned_grounds.csv"

# Save the Series to a CSV file
ground_sorted.to_csv(output_path, index=False)

# %% [markdown]
# #### **Teams**

# %%
teams = set(df["team1"]).union(set(df["team2"]))
teams_df = pd.DataFrame(list(teams), columns=["team"]).sort_values(by="team").drop_duplicates(ignore_index=True)
teams_df.to_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\teams.csv")

# %%
teams_df
# Out:
#                         team
# 0     "Durbans Super Giants"
# 1    Abu Dhabi Knight Riders
# 2          Adelaide Strikers
# 3                Afghanistan
# 4                  Africa XI
# ..                       ...
# 344           Worcestershire
# 345                Yorkshire
# 346       Yorkshire Diamonds
# 347                   Zambia
# 348                 Zimbabwe
#
# [349 rows x 1 columns]

# %%
ipl = df[df["event_name"] == "Indian Premier League"]
ipl_teams = set(ipl["team1"]).union(ipl['team2'])
ipl_teams
# Out:
# {'Chennai Super Kings',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Delhi Daredevils',
#  'Gujarat Lions',
#  'Gujarat Titans',
#  'Kings XI Punjab',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Lucknow Super Giants',
#  'Mumbai Indians',
#  'Pune Warriors',
#  'Punjab Kings',
#  'Rajasthan Royals',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiants',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bengaluru',
#  'Sunrisers Hyderabad'}

# %%
# Dictionary to map team name variations to abbreviations
team_name_mapping = {
    'Chennai Super Kings': 'CSK',
    'Deccan Chargers': 'SRH',
    'Delhi Capitals': 'DC',
    'Delhi Daredevils': 'DC',
    'Gujarat Lions': 'GL',
    'Gujarat Titans': 'GT',
    'Kings XI Punjab': 'PBKS',
    'Kochi Tuskers Kerala': 'KTK',
    'Kolkata Knight Riders': 'KKR',
    'Lucknow Super Giants': 'LSG',
    'Mumbai Indians': 'MI',
    'Pune Warriors': 'PW',
    'Punjab Kings': 'PBKS',
    'Rajasthan Royals': 'RR',
    'Rising Pune Supergiant': 'RPS',
    'Rising Pune Supergiants': 'RPS',
    'Royal Challengers Bangalore': 'RCB',
    'Royal Challengers Bengaluru': 'RCB',
    'Sunrisers Hyderabad': 'SRH',
    '"Durbans Super Giants"': "Durbans Super Giants",
    "United States Of America" : "USA"
}

# Apply the mapping to team1, team2, toss_winner, and winner columns
df['team1'] = df['team1'].replace(team_name_mapping)
df['team2'] = df['team2'].replace(team_name_mapping)
df["toss_winner"] = df['toss_winner'].replace(team_name_mapping)
df['winner'] = df['winner'].replace(team_name_mapping)

# If there are any unmapped values, you might want to investigate and handle them accordingly.

# %%
ipl = df[df["event_name"] == "Indian Premier League"]
ipl_teams = set(ipl["team1"]).union(ipl['team2'])
ipl_teams
# Out:
# {'CSK',
#  'DC',
#  'GL',
#  'GT',
#  'KKR',
#  'KTK',
#  'LSG',
#  'MI',
#  'PBKS',
#  'PW',
#  'RCB',
#  'RPS',
#  'RR',
#  'SRH'}

# %%
replacements = {
    "NatWest T20 Blast": "Vitality Blast",
    "HRV Twenty20": "Super Smash",
    "HRV Cup": "Super Smash",
    "MiWAY T20 Challenge": "CSA T20 Challenge",
    "Ram Slam T20 Challenge": "CSA T20 Challenge"
}

df["event_name"] = df["event_name"].replace(replacements, regex=True)

# %%
df['event_name'] = df['event_name'].replace("Indian Premier League","IPL", regex=True)

# %%
df
# Out:
#       match_id  season match_date                           event_name  \
# 0      1438104    2024 2024-06-19  Hong Kong Women tour of Netherlands
# 1      1438101    2024 2024-06-19         Estonia Women tour of Cyprus
# 2      1438080    2024 2024-06-19               Estonia tour of Cyprus
# 3      1438079    2024 2024-06-19               Estonia tour of Cyprus
# 4      1438105    2024 2024-06-19  Hong Kong Women tour of Netherlands
# ...        ...     ...        ...                                  ...
# 17177    64816    2003 2003-01-04            India tour of New Zealand
# 17178    64815    2003 2003-01-01            India tour of New Zealand
# 17179    64012    2002 2002-12-30            England tour of Australia
# 17180    64022    2002 2002-12-29        Pakistan tour of South Africa
# 17181    64814    2002 2002-12-29            India tour of New Zealand
#
#        gender match_type         team1        team2  toss_winner  \
# 0      female        T20     Hong Kong  Netherlands  Netherlands
# 1      female        T20        Cyprus      Estonia      Estonia
# 2        male        T20       Estonia       Cyprus      Estonia
# 3        male        T20       Estonia       Cyprus       Cyprus
# 4      female        T20   Netherlands    Hong Kong  Netherlands
# ...       ...        ...           ...          ...          ...
# 17177    male        ODI         India  New Zealand  New Zealand
# 17178    male        ODI         India  New Zealand        India
# 17179    male       Test     Australia      England    Australia
# 17180    male       Test  South Africa     Pakistan     Pakistan
# 17181    male        ODI   New Zealand        India        India
#
#       toss_decision        winner                                ground
# 0             field   Netherlands  Sportpark Maarschalkerweerd, Utrecht
# 1             field        Cyprus         Happy Valley Ground, Episkopi
# 2               bat       Estonia         Happy Valley Ground, Episkopi
# 3             field        Cyprus         Happy Valley Ground, Episkopi
# 4               bat   Netherlands  Sportpark Maarschalkerweerd, Utrecht
# ...             ...           ...                                   ...
# 17177         field   New Zealand               Davies Park, Queenstown
# 17178           bat   New Zealand            Jade Stadium, Christchurch
# 17179           bat     Australia   Melbourne Cricket Ground, Melbourne
# 17180         field  South Africa                     Kingsmead, Durban
# 17181         field   New Zealand                   McLean Park, Napier
#
# [17182 rows x 12 columns]

# %%
df.to_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\summary_cleaned.csv")

# %%
df.head()
# Out:
#   match_id  season match_date                           event_name  gender  \
# 0  1438104    2024 2024-06-19  Hong Kong Women tour of Netherlands  female
# 1  1438101    2024 2024-06-19         Estonia Women tour of Cyprus  female
# 2  1438080    2024 2024-06-19               Estonia tour of Cyprus    male
# 3  1438079    2024 2024-06-19               Estonia tour of Cyprus    male
# 4  1438105    2024 2024-06-19  Hong Kong Women tour of Netherlands  female
#
#   match_type        team1        team2  toss_winner toss_decision  \
# 0        T20    Hong Kong  Netherlands  Netherlands         field
# 1        T20       Cyprus      Estonia      Estonia         field
# 2        T20      Estonia       Cyprus      Estonia           bat
# 3        T20      Estonia       Cyprus       Cyprus         field
# 4        T20  Netherlands    Hong Kong  Netherlands           bat
#
#         winner                                ground
# 0  Netherlands  Sportpark Maarschalkerweerd, Utrecht
# 1       Cyprus         Happy Valley Ground, Episkopi
# 2      Estonia         Happy Valley Ground, Episkopi
# 3       Cyprus         Happy Valley Ground, Episkopi
# 4  Netherlands  Sportpark Maarschalkerweerd, Utrecht

# %% [markdown]
# ### **Summary**

# %%
import pandas as pd
summary_df = pd.read_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\summary_cleaned.csv")
summary_df.drop(columns="Unnamed: 0", inplace=True)
summary_df
# Out:
#       match_id  season  match_date                           event_name  \
# 0      1438104    2024  2024-06-19  Hong Kong Women tour of Netherlands
# 1      1438101    2024  2024-06-19         Estonia Women tour of Cyprus
# 2      1438080    2024  2024-06-19               Estonia tour of Cyprus
# 3      1438079    2024  2024-06-19               Estonia tour of Cyprus
# 4      1438105    2024  2024-06-19  Hong Kong Women tour of Netherlands
# ...        ...     ...         ...                                  ...
# 17177    64816    2003  2003-01-04            India tour of New Zealand
# 17178    64815    2003  2003-01-01            India tour of New Zealand
# 17179    64012    2002  2002-12-30            England tour of Australia
# 17180    64022    2002  2002-12-29        Pakistan tour of South Africa
# 17181    64814    2002  2002-12-29            India tour of New Zealand
#
#        gender match_type         team1        team2  toss_winner  \
# 0      female        T20     Hong Kong  Netherlands  Netherlands
# 1      female        T20        Cyprus      Estonia      Estonia
# 2        male        T20       Estonia       Cyprus      Estonia
# 3        male        T20       Estonia       Cyprus       Cyprus
# 4      female        T20   Netherlands    Hong Kong  Netherlands
# ...       ...        ...           ...          ...          ...
# 17177    male        ODI         India  New Zealand  New Zealand
# 17178    male        ODI         India  New Zealand        India
# 17179    male       Test     Australia      England    Australia
# 17180    male       Test  South Africa     Pakistan     Pakistan
# 17181    male        ODI   New Zealand        India        India
#
#       toss_decision        winner                                ground
# 0             field   Netherlands  Sportpark Maarschalkerweerd, Utrecht
# 1             field        Cyprus         Happy Valley Ground, Episkopi
# 2               bat       Estonia         Happy Valley Ground, Episkopi
# 3             field        Cyprus         Happy Valley Ground, Episkopi
# 4               bat   Netherlands  Sportpark Maarschalkerweerd, Utrecht
# ...             ...           ...                                   ...
# 17177         field   New Zealand               Davies Park, Queenstown
# 17178           bat   New Zealand            Jade Stadium, Christchurch
# 17179           bat     Australia   Melbourne Cricket Ground, Melbourne
# 17180         field  South Africa                     Kingsmead, Durban
# 17181         field   New Zealand                   McLean Park, Napier
#
# [17182 rows x 12 columns]

# %%
no_result_df = summary_df[(summary_df['winner'] != summary_df['team1']) & (summary_df['winner'] != summary_df['team2'])].reset_index(drop=True)
no_result_df
# Out:
#      match_id  season  match_date  \
# 0     1410420    2024  2024-06-15
# 1     1410414    2024  2024-06-14
# 2     1410417    2024  2024-06-14
# 3     1415706    2024  2024-06-04
# 4     1430837    2024  2024-05-28
# ...       ...     ...         ...
# 1224    66356    2003  2003-04-21
# 1225    65273    2003  2003-03-04
# 1226    65272    2003  2003-03-03
# 1227    67517    2003  2003-02-25
# 1228    65249    2003  2003-02-18
#
#                                             event_name  gender match_type  \
# 0                                       Vitality Blast    male        T20
# 1                                       Vitality Blast    male        T20
# 2                                       Vitality Blast    male        T20
# 3                              ICC Men's T20 World Cup    male        T20
# 4     Cricket Ireland Inter-Provincial Twenty20 Trophy    male        T20
# ...                                                ...     ...        ...
# 1224                              TVS Cup (Bangladesh)    male        ODI
# 1225                                     ICC World Cup    male        ODI
# 1226                                     ICC World Cup    male        ODI
# 1227                   England Women tour of Australia  female       Test
# 1228                                     ICC World Cup    male        ODI
#
#                  team1            team2      toss_winner toss_decision  \
# 0               Durham  Nottinghamshire  Nottinghamshire         field
# 1            Middlesex        Hampshire        Hampshire         field
# 2      Gloucestershire           Surrey           Surrey         field
# 3             Scotland          England         Scotland           bat
# 4     Northern Knights     Munster Reds     Munster Reds         field
# ...                ...              ...              ...           ...
# 1224             India     South Africa            India           bat
# 1225          Pakistan         Zimbabwe         Pakistan           bat
# 1226         Sri Lanka     South Africa        Sri Lanka           bat
# 1227         Australia          England          England         field
# 1228       West Indies       Bangladesh       Bangladesh         field
#
#          winner                                         ground
# 0     no result                       Trent Bridge, Nottingham
# 1     no result                     The Rose Bowl, Southampton
# 2           tie                        Kennington Oval, London
# 3     no result          Kensington Oval, Barbados, Bridgetown
# 4     no result  Civil Service Cricket Club, Stormont, Belfast
# ...         ...                                            ...
# 1224  no result            Bangabandhu National Stadium, Dhaka
# 1225  no result                   Queens Sports Club, Bulawayo
# 1226        tie                              Kingsmead, Durban
# 1227       draw                         Bankstown Oval, Sydney
# 1228  no result                       Willowmoore Park, Benoni
#
# [1229 rows x 12 columns]

# %%
no_result_df[no_result_df["event_name"] == "IPL"]
# Out:
#      match_id  season  match_date event_name gender match_type team1 team2  \
# 169   1359519    2023  2023-05-03        IPL   male        T20   LSG   CSK
# 571   1178424    2019  2019-04-30        IPL   male        T20   RCB    RR
# 929    829813    2015  2015-05-17        IPL   male        T20   RCB    DC
# 939    829763    2015  2015-04-29        IPL   male        T20   RCB    RR
# 1104   501265    2011  2011-05-21        IPL   male        T20    DC    PW
#
#      toss_winner toss_decision     winner  \
# 169          CSK         field  no result
# 571           RR         field  no result
# 929          RCB         field  no result
# 939           RR         field  no result
# 1104          DC           bat  no result
#
#                                                  ground
# 169   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 571                    M Chinnaswamy Stadium, Bengaluru
# 929                    M Chinnaswamy Stadium, Bengaluru
# 939                    M Chinnaswamy Stadium, Bengaluru
# 1104                            Feroz Shah Kotla, Delhi

# %% [markdown]
# ### **Gender**

# %%
summary_df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %% [markdown]
# ### **Match type**

# %%
summary_df['match_type'].unique()
# Out:
# array(['T20', 'ODI', 'ODM', 'MDM', 'Test', 'IT20'], dtype=object)

# %%
summary_df['match_type'] = summary_df['match_type'].replace("IT20","T20",regex=False)

# %%
summary_df['match_type'].unique()
# Out:
# array(['T20', 'ODI', 'ODM', 'MDM', 'Test'], dtype=object)

# %%
summary_df["match_id"].duplicated().sum()
# Out:
# 0

# %%
print("Length of Data Frame:", len(summary_df))
summary_df.to_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\male\summary_cleaned.csv")
summary_df.to_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\female\summary_cleaned.csv")
# Out:
# Length of Data Frame: 17182

# %%
male = summary_df[summary_df["gender"] == "male"]
female = summary_df[summary_df["gender"] == "female"]

# %%
male.to_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\male\male_summary_cleaned.csv")
female.to_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\female\female_summary_cleaned.csv")
match_types = summary_df["match_type"].drop_duplicates().reset_index(drop=True)
match_types.to_csv(r"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\match_types.csv")

# %% [markdown]
# ### **T20's**

# %%
import pandas as pd
# Enter the Gender
gender = input("Enter Gender: ")

summary_df = pd.read_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\{gender}_summary_cleaned.csv")
summary_df.drop(columns=["Unnamed: 0"], inplace=True)
summary_df
# Out:
#      match_id  season  match_date                               event_name  \
# 0     1438104    2024  2024-06-19      Hong Kong Women tour of Netherlands
# 1     1438101    2024  2024-06-19             Estonia Women tour of Cyprus
# 2     1438105    2024  2024-06-19      Hong Kong Women tour of Netherlands
# 3     1436887    2024  2024-06-18      West Indies Women tour of Sri Lanka
# 4     1438099    2024  2024-06-18             Estonia Women tour of Cyprus
# ...       ...     ...         ...                                      ...
# 2927   271466    2007  2007-01-24      Pakistan Women tour of South Africa
# 2928   271465    2007  2007-01-22      Pakistan Women tour of South Africa
# 2929   225164    2006  2006-08-11  India Women tour of Ireland and England
# 2930   216932    2005  2005-08-27          Australia Women tour of England
# 2931    67517    2003  2003-02-25          England Women tour of Australia
#
#       gender match_type         team1         team2  toss_winner  \
# 0     female        T20     Hong Kong   Netherlands  Netherlands
# 1     female        T20        Cyprus       Estonia      Estonia
# 2     female        T20   Netherlands     Hong Kong  Netherlands
# 3     female        ODI   West Indies     Sri Lanka  West Indies
# 4     female        T20        Cyprus       Estonia      Estonia
# ...      ...        ...           ...           ...          ...
# 2927  female        ODI      Pakistan  South Africa     Pakistan
# 2928  female        ODI  South Africa      Pakistan     Pakistan
# 2929  female       Test       England         India      England
# 2930  female       Test     Australia       England      England
# 2931  female       Test     Australia       England      England
#
#      toss_decision        winner  \
# 0            field   Netherlands
# 1            field        Cyprus
# 2              bat   Netherlands
# 3              bat     Sri Lanka
# 4            field        Cyprus
# ...            ...           ...
# 2927           bat  South Africa
# 2928         field  South Africa
# 2929           bat          draw
# 2930         field       England
# 2931         field          draw
#
#                                                  ground
# 0                  Sportpark Maarschalkerweerd, Utrecht
# 1                         Happy Valley Ground, Episkopi
# 2                  Sportpark Maarschalkerweerd, Utrecht
# 3     Mahinda Rajapaksa International Cricket Stadiu...
# 4                         Happy Valley Ground, Episkopi
# ...                                                 ...
# 2927                 Sinovich Park, Sinoville, Pretoria
# 2928                               Harlequins, Pretoria
# 2929                              Grace Road, Leicester
# 2930                 County Ground, New Road, Worcester
# 2931                             Bankstown Oval, Sydney
#
# [2932 rows x 12 columns]

# %%
t20 = summary_df[summary_df['match_type'] == "T20"].sort_values(by=["match_date","match_id"], ascending=False).reset_index(drop=True)
t20[:5]
# Out:
#   match_id  season  match_date                           event_name  gender  \
# 0  1438105    2024  2024-06-19  Hong Kong Women tour of Netherlands  female
# 1  1438104    2024  2024-06-19  Hong Kong Women tour of Netherlands  female
# 2  1438101    2024  2024-06-19         Estonia Women tour of Cyprus  female
# 3  1438103    2024  2024-06-18  Hong Kong Women tour of Netherlands  female
# 4  1438099    2024  2024-06-18         Estonia Women tour of Cyprus  female
#
#   match_type        team1        team2  toss_winner toss_decision  \
# 0        T20  Netherlands    Hong Kong  Netherlands           bat
# 1        T20    Hong Kong  Netherlands  Netherlands         field
# 2        T20       Cyprus      Estonia      Estonia         field
# 3        T20    Hong Kong  Netherlands  Netherlands         field
# 4        T20       Cyprus      Estonia      Estonia         field
#
#         winner                                ground
# 0  Netherlands  Sportpark Maarschalkerweerd, Utrecht
# 1  Netherlands  Sportpark Maarschalkerweerd, Utrecht
# 2       Cyprus         Happy Valley Ground, Episkopi
# 3  Netherlands  Sportpark Maarschalkerweerd, Utrecht
# 4       Cyprus         Happy Valley Ground, Episkopi

# %%
t20.isnull().sum()
# Out:
# match_id         0
# season           0
# match_date       0
# event_name       4
# gender           0
# match_type       0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# ground           0
# dtype: int64

# %%
t20.to_csv(rf"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\T20_{gender}_match_summary_cleaned.csv")

# %% [markdown]
# ### **IT20's**

# %%
it20 = summary_df[summary_df['match_type'] == "IT20"].sort_values(by=["match_date","match_id"], ascending=False).reset_index(drop=True)
it20
# Out:
# Empty DataFrame
# Columns: [match_id, season, match_date, event_name, gender, match_type, team1, team2, toss_winner, toss_decision, winner, ground]
# Index: []

# %%
it20.isnull().sum()
# Out:
# match_id         0
# season           0
# match_date       0
# event_name       0
# gender           0
# match_type       0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# ground           0
# dtype: int64

# %%
it20.to_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\IT20_{gender}_match_summary_cleaned.csv")

# %% [markdown]
# ### **ODI's**

# %%
odi = summary_df[summary_df['match_type'] == "ODI"].sort_values(by=["match_date","match_id"], ascending=False).reset_index(drop=True)
odi
# Out:
#     match_id  season  match_date                               event_name  \
# 0    1436887    2024  2024-06-18      West Indies Women tour of Sri Lanka
# 1    1434287    2024  2024-06-16         South Africa Women tour of India
# 2    1436886    2024  2024-06-15      West Indies Women tour of Sri Lanka
# 3    1398273    2024  2024-05-29           Pakistan Women tour of England
# 4    1398272    2024  2024-05-26           Pakistan Women tour of England
# ..       ...     ...         ...                                      ...
# 433   312295    2008  2008-02-22  ICC Women's World Cup Qualifying Series
# 434   312291    2008  2008-02-21  ICC Women's World Cup Qualifying Series
# 435   276226    2007  2007-03-05              Women's Quadrangular Series
# 436   271466    2007  2007-01-24      Pakistan Women tour of South Africa
# 437   271465    2007  2007-01-22      Pakistan Women tour of South Africa
#
#      gender match_type         team1         team2   toss_winner  \
# 0    female        ODI   West Indies     Sri Lanka   West Indies
# 1    female        ODI         India  South Africa         India
# 2    female        ODI   West Indies     Sri Lanka     Sri Lanka
# 3    female        ODI       England      Pakistan       England
# 4    female        ODI      Pakistan       England      Pakistan
# ..      ...        ...           ...           ...           ...
# 433  female        ODI       Ireland  South Africa       Ireland
# 434  female        ODI  South Africa   Netherlands  South Africa
# 435  female        ODI   New Zealand     Australia   New Zealand
# 436  female        ODI      Pakistan  South Africa      Pakistan
# 437  female        ODI  South Africa      Pakistan      Pakistan
#
#     toss_decision        winner  \
# 0             bat     Sri Lanka
# 1             bat         India
# 2           field     Sri Lanka
# 3             bat       England
# 4             bat     no result
# ..            ...           ...
# 433           bat  South Africa
# 434           bat  South Africa
# 435           bat     Australia
# 436           bat  South Africa
# 437         field  South Africa
#
#                                                 ground
# 0    Mahinda Rajapaksa International Cricket Stadiu...
# 1                     M Chinnaswamy Stadium, Bengaluru
# 2    Mahinda Rajapaksa International Cricket Stadiu...
# 3                            County Ground, Chelmsford
# 4         The Cooper Associates County Ground, Taunton
# ..                                                 ...
# 433                          Stellenbosch University 1
# 434                          Stellenbosch University 1
# 435           MA Chidambaram Stadium, Chepauk, Chennai
# 436                 Sinovich Park, Sinoville, Pretoria
# 437                               Harlequins, Pretoria
#
# [438 rows x 12 columns]

# %%
odi.isnull().sum()
# Out:
# match_id         0
# season           0
# match_date       0
# event_name       0
# gender           0
# match_type       0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# ground           0
# dtype: int64

# %%
odi.to_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\ODI_{gender}_match_summary_cleaned.csv")

# %% [markdown]
# ### **ODM's**

# %%
odm = summary_df[summary_df['match_type'] == "ODM"].sort_values(by=["match_date","match_id"], ascending=False).reset_index(drop=True)
odm
# Out:
#     match_id  season  match_date  \
# 0    1427829    2024  2024-05-08
# 1    1427828    2024  2024-05-08
# 2    1427827    2024  2024-05-08
# 3    1427826    2024  2024-05-08
# 4    1427825    2024  2024-05-06
# ..       ...     ...         ...
# 188  1073407    2017  2017-02-08
# 189  1073406    2017  2017-02-08
# 190  1073404    2017  2017-02-07
# 191  1073402    2017  2017-02-07
# 192  1033707    2016  2016-07-15
#
#                                             event_name  gender match_type  \
# 0                          Rachael Heyhoe Flint Trophy  female        ODM
# 1                          Rachael Heyhoe Flint Trophy  female        ODM
# 2                          Rachael Heyhoe Flint Trophy  female        ODM
# 3                          Rachael Heyhoe Flint Trophy  female        ODM
# 4                          Rachael Heyhoe Flint Trophy  female        ODM
# ..                                                 ...     ...        ...
# 188                    ICC Women's World Cup Qualifier  female        ODM
# 189                    ICC Women's World Cup Qualifier  female        ODM
# 190                    ICC Women's World Cup Qualifier  female        ODM
# 191                    ICC Women's World Cup Qualifier  female        ODM
# 192  ICC Women's World Cup Qualifying Series Europe...  female        ODM
#
#                  team1             team2        toss_winner toss_decision  \
# 0        Western Storm         The Blaze          The Blaze         field
# 1              Thunder    Central Sparks            Thunder           bat
# 2      Southern Vipers         Sunrisers          Sunrisers         field
# 3    Northern Diamonds  South East Stars  Northern Diamonds           bat
# 4            The Blaze           Thunder            Thunder         field
# ..                 ...               ...                ...           ...
# 188           Scotland      South Africa           Scotland           bat
# 189              India          Thailand           Thailand           bat
# 190         Bangladesh  Papua New Guinea         Bangladesh           bat
# 191            Ireland          Zimbabwe           Zimbabwe         field
# 192        Netherlands          Scotland        Netherlands           bat
#
#                 winner                                          ground
# 0            The Blaze                        Trent Bridge, Nottingham
# 1       Central Sparks                        Old Trafford, Manchester
# 2            Sunrisers                   Radlett Cricket Club, Radlett
# 3    Northern Diamonds           Kent County Cricket Ground, Beckenham
# 4              Thunder                        Trent Bridge, Nottingham
# ..                 ...                                             ...
# 188       South Africa  Mercantile Cricket Association Ground, Colombo
# 189              India                     Colombo Cricket Club Ground
# 190         Bangladesh                     Colombo Cricket Club Ground
# 191            Ireland  Mercantile Cricket Association Ground, Colombo
# 192           Scotland                     Garon Park, Southend-on-Sea
#
# [193 rows x 12 columns]

# %%
odm.isnull().sum()
# Out:
# match_id         0
# season           0
# match_date       0
# event_name       0
# gender           0
# match_type       0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# ground           0
# dtype: int64

# %%
odm.to_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\ODM_{gender}_match_summary_cleaned.csv")

# %% [markdown]
# ### **MDM's**

# %%
mdm = summary_df[summary_df['match_type'] == "MDM"].sort_values(by=["match_date","match_id"], ascending=False).reset_index(drop=True)
mdm
# Out:
# Empty DataFrame
# Columns: [match_id, season, match_date, event_name, gender, match_type, team1, team2, toss_winner, toss_decision, winner, ground]
# Index: []

# %%
mdm.isnull().sum()
# Out:
# match_id         0
# season           0
# match_date       0
# event_name       0
# gender           0
# match_type       0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# ground           0
# dtype: int64

# %%
mdm.to_csv(fr"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\MDM_{gender}_match_summary_cleaned.csv")

# %% [markdown]
# ### **Test's**

# %%
test = summary_df[summary_df['match_type'] == "Test"].sort_values(by=["match_date","match_id"], ascending=False).reset_index(drop=True)
test
# Out:
#    match_id  season  match_date  \
# 0   1375875    2024  2024-02-17
# 1   1406077    2023  2023-12-24
# 2   1406076    2023  2023-12-16
# 3   1336073    2023  2023-06-26
# 4   1301327    2022  2022-06-30
# 5   1263571    2022  2022-01-30
# 6   1263620    2021  2021-10-03
# 7   1260093    2021  2021-06-19
# 8   1168025    2019  2019-07-21
# 9   1086066    2017  2017-11-12
# 10   798375    2015  2015-08-14
# 11   722387    2014  2014-08-16
# 12   593722    2013  2013-08-14
# 13   474625    2011  2011-01-25
# 14   383288    2009  2009-07-13
# 15   312450    2008  2008-02-18
# 16   225164    2006  2006-08-11
# 17   216932    2005  2005-08-27
# 18    67517    2003  2003-02-25
#
#                                          event_name  gender match_type  \
# 0              South Africa Women tour of Australia  female       Test
# 1                     Australia Women tour of India  female       Test
# 2                       England Women tour of India  female       Test
# 3                                     Women's Ashes  female       Test
# 4                South Africa Women tour of England  female       Test
# 5                                     Women's Ashes  female       Test
# 6                     India Women tour of Australia  female       Test
# 7                       India Women tour of England  female       Test
# 8                   Australia Women tour of England  female       Test
# 9                                     Women's Ashes  female       Test
# 10                                    Women's Ashes  female       Test
# 11                                              NaN  female       Test
# 12                                    Women's Ashes  female       Test
# 13                  England Women tour of Australia  female       Test
# 14                  Australia Women tour of England  female       Test
# 15  England Women tour of Australia and New Zealand  female       Test
# 16          India Women tour of Ireland and England  female       Test
# 17                  Australia Women tour of England  female       Test
# 18                  England Women tour of Australia  female       Test
#
#            team1      team2 toss_winner toss_decision     winner  \
# 0   South Africa  Australia   Australia         field  Australia
# 1      Australia      India   Australia           bat      India
# 2          India    England       India           bat      India
# 3      Australia    England   Australia           bat  Australia
# 4   South Africa    England     England         field       draw
# 5      Australia    England     England         field       draw
# 6          India  Australia   Australia         field       draw
# 7        England      India     England           bat       draw
# 8        England  Australia   Australia           bat       draw
# 9        England  Australia     England           bat       draw
# 10       England  Australia   Australia           bat  Australia
# 11       England      India       India         field      India
# 12       England  Australia   Australia           bat       draw
# 13       England  Australia     England           bat  Australia
# 14     Australia    England   Australia           bat       draw
# 15     Australia    England     England         field    England
# 16       England      India     England           bat       draw
# 17     Australia    England     England         field    England
# 18     Australia    England     England         field       draw
#
#                                                ground
# 0   Western Australia Cricket Association Ground, ...
# 1                            Wankhede Stadium, Mumbai
# 2     Dr DY Patil Sports Academy, Mumbai, Navi Mumbai
# 3                            Trent Bridge, Nottingham
# 4        The Cooper Associates County Ground, Taunton
# 5                               Manuka Oval, Canberra
# 6                               Carrara Oval, Carrara
# 7                              County Ground, Bristol
# 8        The Cooper Associates County Ground, Taunton
# 9                           North Sydney Oval, Sydney
# 10                     St Lawrence Ground, Canterbury
# 11                  Sir Paul Getty's Ground, Wormsley
# 12                  Sir Paul Getty's Ground, Wormsley
# 13                             Bankstown Oval, Sydney
# 14                 County Ground, New Road, Worcester
# 15                               Bradman Oval, Bowral
# 16                              Grace Road, Leicester
# 17                 County Ground, New Road, Worcester
# 18                             Bankstown Oval, Sydney

# %%
test.isnull().sum()
# Out:
# match_id         0
# season           0
# match_date       0
# event_name       1
# gender           0
# match_type       0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# ground           0
# dtype: int64

# %%
test.to_csv(rf"D:\GITHUB\Predictive-Analytics-for-Cricket-Matches-Using-Machine-Learning\source_data\Summary\match_summary\{gender}\Test_{gender}_match_summary_cleaned.csv")
